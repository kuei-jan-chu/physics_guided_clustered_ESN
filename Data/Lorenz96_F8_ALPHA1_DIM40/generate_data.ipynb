# %% [markdown]
# # Generate lorenz96 data with F = 8 and dimension = 40

# %% [markdown]
# ## generate data

# %%
# %run ./0_data_generation.py
# Out:
# # F=8
# Script to generate data for Lorenz96 for F=8
# Generating time-series with 200000 data-points
# Get past initial transients
#
# 100000/100000
# Generate time series
#
# 200000/200000

# %% [markdown]
# ## calculate the Maximum lyapunov exponent

# %%
# %run ./1_mle_calculation.py
# Out:
# /Users/kuei_jan_chu/Desktop/new_pgc_esn/Data/Lorenz96_F8_ALPHA1_DIM40/1_mle_calculation.py:35: DeprecationWarning: numpy.core.numeric is deprecated and has been renamed to numpy._core.numeric. The numpy._core namespace contains private NumPy internals and its use is discouraged, as NumPy internals can change without warning in any release. In practice, most real-world usage of numpy.core is to access functionality in the public NumPy API. If that is the case, use the public NumPy API. If not, you are using NumPy internals. If you would still like to access an internal attribute, use numpy._core.numeric._frombuffer.
#   data = pickle.load(file)
# MAXIMUM LYAPUNOV EXPONENT = 1.690650590094699

# %%
## calculate transfer entropy
# %run ./2_transfer_entropy_extraction_3000.py
# Out:
# Correct coupling recovery accuracy: 89.17%

# %%
# %run ./2_transfer_entropy_extraction_100000.py
# Out:
# Correct coupling recovery accuracy: 100.00%

# %% [markdown]
# ## seperate data to train and test

# %%
# %run ./3_create_training_data_10000.py
# Out:
# Total data shape:
# (200000, 40)
# Traing data shape:
# (10000, 40)
# Test data shape:
# (100000, 40)
# attractor_std shape:
# (40,)
# train_input_sequence shape:
# (10000, 40)
# test_input_sequence shape:
# (100000, 40)

# %%
# %run ./3_create_training_data_20000.py
# Out:
# Total data shape:
# (200000, 40)
# Traing data shape:
# (20000, 40)
# Test data shape:
# (100000, 40)
# attractor_std shape:
# (40,)
# train_input_sequence shape:
# (20000, 40)
# test_input_sequence shape:
# (100000, 40)

# %%
# %run ./3_create_training_data_30000.py
# Out:
# Total data shape:
# (200000, 40)
# Traing data shape:
# (30000, 40)
# Test data shape:
# (100000, 40)
# attractor_std shape:
# (40,)
# train_input_sequence shape:
# (30000, 40)
# test_input_sequence shape:
# (100000, 40)

# %%
# %run ./3_create_training_data_40000.py
# Out:
# Total data shape:
# (200000, 40)
# Traing data shape:
# (40000, 40)
# Test data shape:
# (100000, 40)
# attractor_std shape:
# (40,)
# train_input_sequence shape:
# (40000, 40)
# test_input_sequence shape:
# (100000, 40)

# %%
# %run ./3_create_training_data_50000.py
# Out:
# Total data shape:
# (200000, 40)
# Traing data shape:
# (50000, 40)
# Test data shape:
# (100000, 40)
# attractor_std shape:
# (40,)
# train_input_sequence shape:
# (50000, 40)
# test_input_sequence shape:
# (100000, 40)

# %%
# %run ./3_create_training_data_60000.py
# Out:
# Total data shape:
# (200000, 40)
# Traing data shape:
# (60000, 40)
# Test data shape:
# (100000, 40)
# attractor_std shape:
# (40,)
# train_input_sequence shape:
# (60000, 40)
# test_input_sequence shape:
# (100000, 40)

# %%
# %run ./3_create_training_data_70000.py
# Out:
# Total data shape:
# (200000, 40)
# Traing data shape:
# (70000, 40)
# Test data shape:
# (100000, 40)
# attractor_std shape:
# (40,)
# train_input_sequence shape:
# (70000, 40)
# test_input_sequence shape:
# (100000, 40)

# %%
# %run ./3_create_training_data_80000.py
# Out:
# Total data shape:
# (200000, 40)
# Traing data shape:
# (80000, 40)
# Test data shape:
# (100000, 40)
# attractor_std shape:
# (40,)
# train_input_sequence shape:
# (80000, 40)
# test_input_sequence shape:
# (100000, 40)

# %%
# %run ./3_create_training_data_90000.py
# Out:
# Total data shape:
# (200000, 40)
# Traing data shape:
# (90000, 40)
# Test data shape:
# (100000, 40)
# attractor_std shape:
# (40,)
# train_input_sequence shape:
# (90000, 40)
# test_input_sequence shape:
# (100000, 40)

# %%
# %run ./3_create_training_data_100000.py
# Out:
# Total data shape:
# (200000, 40)
# Traing data shape:
# (100000, 40)
# Test data shape:
# (100000, 40)
# attractor_std shape:
# (40,)
# train_input_sequence shape:
# (100000, 40)
# test_input_sequence shape:
# (100000, 40)

# %% [markdown]
# ## seperate train data to training and validation parts for hyperparameters tuning

# %%
# %run ./4_create_tuning_data.py
# Out:
# Traing data shape:
# (60000, 40)
# Test data shape:
# (40000, 40)

# %% [markdown]
# ## Plot figures

# %%
# %run ./5_create_figures.py
