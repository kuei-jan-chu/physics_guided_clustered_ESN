# %% [markdown]
# # noise level 5, metric: d_temp

# %%
# !bash ./3_PGClustered_ESN_Train.sh
# Out:
# CUDA Device available? True
# Using device: cuda
# DEVICE NAME: NVIDIA GeForce RTX 4090
# MEMORY USAGE:
# Memory allocated: 0.0 GB
# Max memory allocated: 0.0 GB
# Memory cached:    0.0 GB
# MAX memory cached:    0.0 GB
# USING CUDA AND GPU.
# # GPU MEMORY nvidia-smi in MB={0: 1023}
# RANDOM SEED: 0
# Adding noise to the training data. 5 per mille
# ##Using 40/40 dimensions and 100000/100000 samples ##
# SCALING
# Initializing the input weights...
# Initializing the reservoir weights...
# NETWORK SPARSITY: 1.0
# Computing sparse hidden to hidden weight matrix...
# EIGENVALUE DECOMPOSITION
#
# TRAINING: Dynamics prerun...
# TRAINING - Dynamics prerun: T 2000/2000, 100.000%
# TRAINING: Teacher forcing...
# TRAINING - Teacher forcing: T 97999/97999, 100.000%
# TEACHER FORCING ENDED.
#
# TRAINING: COMPUTING THE OUTPUT WEIGHTS...
# FINALISING WEIGHTS...
# COMPUTING NUMBER OF PARAMETERS...
# Number of trainable parameters: 120000
# Total number of parameters: 9240000
# SAVING MODEL...
# ...

# %%
# !bash ./4_PGClustered_ESN_Test.sh
# Out:
# CUDA Device available? True
# Using device: cuda
# DEVICE NAME: NVIDIA GeForce RTX 4090
# MEMORY USAGE:
# Memory allocated: 0.0 GB
# Max memory allocated: 0.0 GB
# Memory cached:    0.0 GB
# MAX memory cached:    0.0 GB
# USING CUDA AND GPU.
# # GPU MEMORY nvidia-smi in MB={0: 1033}
# RANDOM SEED: 0
# TEST ON TRAINING SET
# IC 1/10, 10.000%
# PREDICTION - Dynamics prerun
# PREDICTION - Dynamics prerun: T 2000/2000, 100.000%
# PREDICTION:
# SEQUENCE PREDICTED...00, 100.000%
#
# IC 2/10, 20.000%
# PREDICTION - Dynamics prerun
# PREDICTION - Dynamics prerun: T 2000/2000, 100.000%
# PREDICTION:
# SEQUENCE PREDICTED...00, 100.000%
#
# IC 3/10, 30.000%
# PREDICTION - Dynamics prerun
# PREDICTION - Dynamics prerun: T 2000/2000, 100.000%
# PREDICTION:
# SEQUENCE PREDICTED...00, 100.000%
#
# IC 4/10, 40.000%
# PREDICTION - Dynamics prerun
# PREDICTION - Dynamics prerun: T 2000/2000, 100.000%
# PREDICTION:
# SEQUENCE PREDICTED...00, 100.000%
#
# IC 5/10, 50.000%
# PREDICTION - Dynamics prerun
# ...

# %%
# !bash ./2_PGClustered_ESN_Plot_Tuned_Model.sh "plot_tuned_model" "Lorenz96_F8_ALPHA6_DIM40" 3000 1 1 6 "grid_search.json"
# Out:
# {'radius': 0.4, 'sigma_input': 0.5, 'system_name': 'Lorenz96_F8_ALPHA6_DIM40'}
# /home/user/kuei_jan_CHU/PGClustered_ESN/Methods/./Utils/plotting_utils.py:180: RuntimeWarning: divide by zero encountered in log
#   plt.plot(np.log(np.arange(np.shape(error)[0])), np.log(error), label='log(error)')
# IC_IDX: 44000,
# VMIN: -7
# VMAX: 8
#
# /home/user/kuei_jan_CHU/PGClustered_ESN/Methods/./Utils/plotting_utils.py:180: RuntimeWarning: divide by zero encountered in log
#   plt.plot(np.log(np.arange(np.shape(error)[0])), np.log(error), label='log(error)')
# IC_IDX: 79000,
# VMIN: -6
# VMAX: 7
#
# /home/user/kuei_jan_CHU/PGClustered_ESN/Methods/./Utils/plotting_utils.py:180: RuntimeWarning: divide by zero encountered in log
#   plt.plot(np.log(np.arange(np.shape(error)[0])), np.log(error), label='log(error)')
# IC_IDX: 30000,
# VMIN: -6
# VMAX: 8
#
# /home/user/kuei_jan_CHU/PGClustered_ESN/Methods/./Utils/plotting_utils.py:180: RuntimeWarning: divide by zero encountered in log
# ...

# %%
# !bash ./2_PGClustered_ESN_Plot_Tuned_Model.sh "plot_tuned_model" "Lorenz96_F32_ALPHA1_DIM40" 3000 1 1 12 "grid_search_for_F.json"
# Out:
# {'radius': 0.7, 'sigma_input': 0.5}
# /home/user/kuei_jan_CHU/PGClustered_ESN/Methods/./Utils/plotting_utils.py:180: RuntimeWarning: divide by zero encountered in log
#   plt.plot(np.log(np.arange(np.shape(error)[0])), np.log(error), label='log(error)')
# IC_IDX: 44000,
# VMIN: -31
# VMAX: 40
#
# /home/user/kuei_jan_CHU/PGClustered_ESN/Methods/./Utils/plotting_utils.py:180: RuntimeWarning: divide by zero encountered in log
#   plt.plot(np.log(np.arange(np.shape(error)[0])), np.log(error), label='log(error)')
# IC_IDX: 79000,
# VMIN: -28
# VMAX: 37
#
# /home/user/kuei_jan_CHU/PGClustered_ESN/Methods/./Utils/plotting_utils.py:180: RuntimeWarning: divide by zero encountered in log
#   plt.plot(np.log(np.arange(np.shape(error)[0])), np.log(error), label='log(error)')
# IC_IDX: 30000,
# VMIN: -30
# VMAX: 39
#
# /home/user/kuei_jan_CHU/PGClustered_ESN/Methods/./Utils/plotting_utils.py:180: RuntimeWarning: divide by zero encountered in log
# ...
