# %%
# !bash ./2_Randomly_Clustered_ESN_Plot_Tuned_Model.sh "plot_tuned_model" 500 0.1 0.1 2 "grid_search.json"
# Out:
# {'radius': 0.1, 'sigma_input': 0.1}
# CUDA Device available? True
# Using device: cuda
# DEVICE NAME: NVIDIA GeForce RTX 4090
# MEMORY USAGE:
# Memory allocated: 0.0 GB
# Max memory allocated: 0.0 GB
# Memory cached:    0.0 GB
# MAX memory cached:    0.0 GB
# USING CUDA AND GPU.
# # GPU MEMORY nvidia-smi in MB={0: 1576}
# RANDOM SEED: 0
# TEST ON TRAINING SET
# IC 1/10, 10.000%
# PREDICTION - Dynamics prerun
# PREDICTION - Dynamics prerun: T 2000/2000, 100.000%
# PREDICTION:
# SEQUENCE PREDICTED...00, 100.000%
#
# IC 2/10, 20.000%
# PREDICTION - Dynamics prerun
# PREDICTION - Dynamics prerun: T 2000/2000, 100.000%
# PREDICTION:
# SEQUENCE PREDICTED...00, 100.000%
#
# IC 3/10, 30.000%
# PREDICTION - Dynamics prerun
# PREDICTION - Dynamics prerun: T 2000/2000, 100.000%
# PREDICTION:
# SEQUENCE PREDICTED...00, 100.000%
#
# IC 4/10, 40.000%
# PREDICTION - Dynamics prerun
# PREDICTION - Dynamics prerun: T 2000/2000, 100.000%
# PREDICTION:
# SEQUENCE PREDICTED...00, 100.000%
#
# IC 5/10, 50.000%
# PREDICTION - Dynamics prerun
# PREDICTION - Dynamics prerun: T 2000/2000, 100.000%
# PREDICTION:
# SEQUENCE PREDICTED...00, 100.000%
#
# IC 6/10, 60.000%
# PREDICTION - Dynamics prerun
# PREDICTION - Dynamics prerun: T 2000/2000, 100.000%
# PREDICTION:
# SEQUENCE PREDICTED...00, 100.000%
#
# IC 7/10, 70.000%
# PREDICTION - Dynamics prerun
# PREDICTION - Dynamics prerun: T 2000/2000, 100.000%
# PREDICTION:
# SEQUENCE PREDICTED...00, 100.000%
#
# IC 8/10, 80.000%
# PREDICTION - Dynamics prerun
# PREDICTION - Dynamics prerun: T 2000/2000, 100.000%
# PREDICTION:
# SEQUENCE PREDICTED...00, 100.000%
#
# IC 9/10, 90.000%
# PREDICTION - Dynamics prerun
# PREDICTION - Dynamics prerun: T 2000/2000, 100.000%
# PREDICTION:
# SEQUENCE PREDICTED...00, 100.000%
#
# IC 10/10, 100.000%
# PREDICTION - Dynamics prerun
# PREDICTION - Dynamics prerun: T 2000/2000, 100.000%
# PREDICTION:
# SEQUENCE PREDICTED...00, 100.000%
#
# TRAJECTORIES SHAPES:
# (10, 7000, 40)
# (10, 7000, 40)
# AVERAGE RMNSE ERROR: 3.3223807138646375
# AVG NUMBER OF ACCURATE 0.5 PREDICTIONS: 0.2721947450052466
# AVG NUMBER OF ACCURATE 1 PREDICTIONS: 0.7574114643624252
# POWER SPECTRUM MEAN ERROR: 10.01740820542996
# TEMPORAL DISTANCE: 0.21506328440761413
# GEOMETRICAL DISTANCE: inf
# IC INDEXES OF TRAIN PREDICTED...
#
#
# TEST ON TESTING SET
# IC 1/10, 10.000%
# PREDICTION - Dynamics prerun
# PREDICTION - Dynamics prerun: T 2000/2000, 100.000%
# PREDICTION:
# SEQUENCE PREDICTED...00, 100.000%
#
# IC 2/10, 20.000%
# PREDICTION - Dynamics prerun
# PREDICTION - Dynamics prerun: T 2000/2000, 100.000%
# PREDICTION:
# SEQUENCE PREDICTED...00, 100.000%
#
# IC 3/10, 30.000%
# PREDICTION - Dynamics prerun
# PREDICTION - Dynamics prerun: T 2000/2000, 100.000%
# PREDICTION:
# SEQUENCE PREDICTED...00, 100.000%
#
# IC 4/10, 40.000%
# PREDICTION - Dynamics prerun
# PREDICTION - Dynamics prerun: T 2000/2000, 100.000%
# PREDICTION:
# SEQUENCE PREDICTED...00, 100.000%
#
# IC 5/10, 50.000%
# PREDICTION - Dynamics prerun
# PREDICTION - Dynamics prerun: T 2000/2000, 100.000%
# PREDICTION:
# SEQUENCE PREDICTED...00, 100.000%
#
# IC 6/10, 60.000%
# PREDICTION - Dynamics prerun
# PREDICTION - Dynamics prerun: T 2000/2000, 100.000%
# PREDICTION:
# SEQUENCE PREDICTED...00, 100.000%
#
# IC 7/10, 70.000%
# PREDICTION - Dynamics prerun
# PREDICTION - Dynamics prerun: T 2000/2000, 100.000%
# PREDICTION:
# SEQUENCE PREDICTED...00, 100.000%
#
# IC 8/10, 80.000%
# PREDICTION - Dynamics prerun
# PREDICTION - Dynamics prerun: T 2000/2000, 100.000%
# PREDICTION:
# SEQUENCE PREDICTED...00, 100.000%
#
# IC 9/10, 90.000%
# PREDICTION - Dynamics prerun
# PREDICTION - Dynamics prerun: T 2000/2000, 100.000%
# PREDICTION:
# SEQUENCE PREDICTED...00, 100.000%
#
# IC 10/10, 100.000%
# PREDICTION - Dynamics prerun
# PREDICTION - Dynamics prerun: T 2000/2000, 100.000%
# PREDICTION:
# SEQUENCE PREDICTED...00, 100.000%
#
# TRAJECTORIES SHAPES:
# (10, 7000, 40)
# (10, 7000, 40)
# AVERAGE RMNSE ERROR: 3.3086313111624395
# AVG NUMBER OF ACCURATE 0.5 PREDICTIONS: 0.2383817332033526
# AVG NUMBER OF ACCURATE 1 PREDICTIONS: 0.6847134889883532
# POWER SPECTRUM MEAN ERROR: 11.05447392480864
# TEMPORAL DISTANCE: 0.20674471873116937
# GEOMETRICAL DISTANCE: inf
# IC INDEXES OF TEST PREDICTED...
#
#
# /home/user/kuei_jan_CHU/PGClustered_ESN/Methods/./Utils/plotting_utils.py:206: RuntimeWarning: divide by zero encountered in log
#   plt.plot(np.log(np.arange(np.shape(error)[0])), np.log(error), label='log(error)')
# IC_IDX: 44000,
# VMIN: -7
# VMAX: 11
#
# /home/user/kuei_jan_CHU/PGClustered_ESN/Methods/./Utils/plotting_utils.py:206: RuntimeWarning: divide by zero encountered in log
#   plt.plot(np.log(np.arange(np.shape(error)[0])), np.log(error), label='log(error)')
# IC_IDX: 79000,
# VMIN: -9
# VMAX: 13
#
# /home/user/kuei_jan_CHU/PGClustered_ESN/Methods/./Utils/plotting_utils.py:206: RuntimeWarning: divide by zero encountered in log
#   plt.plot(np.log(np.arange(np.shape(error)[0])), np.log(error), label='log(error)')
# IC_IDX: 30000,
# VMIN: -7
# VMAX: 12
#
# /home/user/kuei_jan_CHU/PGClustered_ESN/Methods/./Utils/plotting_utils.py:206: RuntimeWarning: divide by zero encountered in log
#   plt.plot(np.log(np.arange(np.shape(error)[0])), np.log(error), label='log(error)')
# IC_IDX: 37000,
# VMIN: -7
# VMAX: 12
#
# /home/user/kuei_jan_CHU/PGClustered_ESN/Methods/./Utils/plotting_utils.py:206: RuntimeWarning: divide by zero encountered in log
#   plt.plot(np.log(np.arange(np.shape(error)[0])), np.log(error), label='log(error)')
# IC_IDX: 16000,
# VMIN: -6
# VMAX: 12
#
# /home/user/kuei_jan_CHU/PGClustered_ESN/Methods/./Utils/plotting_utils.py:206: RuntimeWarning: divide by zero encountered in log
#   plt.plot(np.log(np.arange(np.shape(error)[0])), np.log(error), label='log(error)')
# IC_IDX: 23000,
# VMIN: -7
# VMAX: 13

# %%
# !bash ./3_Randomly_Clustered_ESN_Train.sh
# Out:
# CUDA Device available? True
# Using device: cuda
# DEVICE NAME: NVIDIA GeForce RTX 4090
# MEMORY USAGE:
# Memory allocated: 0.0 GB
# Max memory allocated: 0.0 GB
# Memory cached:    0.0 GB
# MAX memory cached:    0.0 GB
# USING CUDA AND GPU.
# # GPU MEMORY nvidia-smi in MB={0: 1591}
# RANDOM SEED: 0
# Adding noise to the training data. 5 per mille
# ##Using 40/40 dimensions and 100000/100000 samples ##
# SCALING
# Initializing the input weights...
# Initializing the reservoir weights...
# NETWORK SPARSITY: 0.1
# Computing sparse hidden to hidden weight matrix...
# EIGENVALUE DECOMPOSITION
#
# TRAINING: Dynamics prerun...
# TRAINING - Dynamics prerun: T 2000/2000, 100.000%
# TRAINING: Teacher forcing...
# TRAINING - Teacher forcing: T 97999/97999, 100.000%
# TEACHER FORCING ENDED.
#
# TRAINING: COMPUTING THE OUTPUT WEIGHTS...
# FINALISING WEIGHTS...
# COMPUTING NUMBER OF PARAMETERS...
# Number of trainable parameters: 60800
# Total number of parameters: 2432000
# SAVING MODEL...
# Recording time...
# Total training time is 15.0320303440094
# MEMORY TRACKING IN MB...
# Script used 2608.34765625 MB
# Saving the model... In path /home/user/kuei_jan_CHU/PGClustered_ESN/Results/Lorenz96_F8_ALPHA1_DIM40/randomly_clustered_esn/Trained_Models/RNN-randomly_clustered_esnLorenz96_F8_ALPHA1_DIM40-RDIM_40-N_train_100000-N_test_100000-SIZE_1500-SP_0.1-RADIUS_0.99-SIGMA_0.5-PIN_0.1-DL_2000-NL_5-IPL_7000-REG_0.01-IGS_1-WID_0/data.pickle

# %%
# !bash ./3_Randomly_Clustered_ESN_Test.sh
# Out:
# CUDA Device available? True
# Using device: cuda
# DEVICE NAME: NVIDIA GeForce RTX 4090
# MEMORY USAGE:
# Memory allocated: 0.0 GB
# Max memory allocated: 0.0 GB
# Memory cached:    0.0 GB
# MAX memory cached:    0.0 GB
# USING CUDA AND GPU.
# # GPU MEMORY nvidia-smi in MB={0: 1265}
# RANDOM SEED: 0
# TEST ON TRAINING SET
# IC 1/10, 10.000%
# PREDICTION - Dynamics prerun
# PREDICTION - Dynamics prerun: T 2000/2000, 100.000%
# PREDICTION:
# SEQUENCE PREDICTED...00, 100.000%
#
# IC 2/10, 20.000%
# PREDICTION - Dynamics prerun
# PREDICTION - Dynamics prerun: T 2000/2000, 100.000%
# PREDICTION:
# SEQUENCE PREDICTED...00, 100.000%
#
# IC 3/10, 30.000%
# PREDICTION - Dynamics prerun
# PREDICTION - Dynamics prerun: T 2000/2000, 100.000%
# PREDICTION:
# SEQUENCE PREDICTED...00, 100.000%
#
# IC 4/10, 40.000%
# PREDICTION - Dynamics prerun
# PREDICTION - Dynamics prerun: T 2000/2000, 100.000%
# PREDICTION:
# SEQUENCE PREDICTED...00, 100.000%
#
# IC 5/10, 50.000%
# PREDICTION - Dynamics prerun
# PREDICTION - Dynamics prerun: T 2000/2000, 100.000%
# PREDICTION:
# SEQUENCE PREDICTED...00, 100.000%
#
# IC 6/10, 60.000%
# PREDICTION - Dynamics prerun
# PREDICTION - Dynamics prerun: T 2000/2000, 100.000%
# PREDICTION:
# SEQUENCE PREDICTED...00, 100.000%
#
# IC 7/10, 70.000%
# PREDICTION - Dynamics prerun
# PREDICTION - Dynamics prerun: T 2000/2000, 100.000%
# PREDICTION:
# SEQUENCE PREDICTED...00, 100.000%
#
# IC 8/10, 80.000%
# PREDICTION - Dynamics prerun
# PREDICTION - Dynamics prerun: T 2000/2000, 100.000%
# PREDICTION:
# SEQUENCE PREDICTED...00, 100.000%
#
# IC 9/10, 90.000%
# PREDICTION - Dynamics prerun
# PREDICTION - Dynamics prerun: T 2000/2000, 100.000%
# PREDICTION:
# SEQUENCE PREDICTED...00, 100.000%
#
# IC 10/10, 100.000%
# PREDICTION - Dynamics prerun
# PREDICTION - Dynamics prerun: T 2000/2000, 100.000%
# PREDICTION:
# SEQUENCE PREDICTED...00, 100.000%
#
# TRAJECTORIES SHAPES:
# (10, 7000, 40)
# (10, 7000, 40)
# AVERAGE RMNSE ERROR: 1.4449668554434987
# AVG NUMBER OF ACCURATE 0.5 PREDICTIONS: 0.2637414920547731
# AVG NUMBER OF ACCURATE 1 PREDICTIONS: 0.7151451996100577
# POWER SPECTRUM MEAN ERROR: 4.128506611194232
# TEMPORAL DISTANCE: 0.1577203390059197
# GEOMETRICAL DISTANCE: 14.66631434339455
# IC INDEXES OF TRAIN PREDICTED...
#
#
# TEST ON TESTING SET
# IC 1/10, 10.000%
# PREDICTION - Dynamics prerun
# PREDICTION - Dynamics prerun: T 2000/2000, 100.000%
# PREDICTION:
# SEQUENCE PREDICTED...00, 100.000%
#
# IC 2/10, 20.000%
# PREDICTION - Dynamics prerun
# PREDICTION - Dynamics prerun: T 2000/2000, 100.000%
# PREDICTION:
# SEQUENCE PREDICTED...00, 100.000%
#
# IC 3/10, 30.000%
# PREDICTION - Dynamics prerun
# PREDICTION - Dynamics prerun: T 2000/2000, 100.000%
# PREDICTION:
# SEQUENCE PREDICTED...00, 100.000%
#
# IC 4/10, 40.000%
# PREDICTION - Dynamics prerun
# PREDICTION - Dynamics prerun: T 2000/2000, 100.000%
# PREDICTION:
# SEQUENCE PREDICTED...00, 100.000%
#
# IC 5/10, 50.000%
# PREDICTION - Dynamics prerun
# PREDICTION - Dynamics prerun: T 2000/2000, 100.000%
# PREDICTION:
# SEQUENCE PREDICTED...00, 100.000%
#
# IC 6/10, 60.000%
# PREDICTION - Dynamics prerun
# PREDICTION - Dynamics prerun: T 2000/2000, 100.000%
# PREDICTION:
# SEQUENCE PREDICTED...00, 100.000%
#
# IC 7/10, 70.000%
# PREDICTION - Dynamics prerun
# PREDICTION - Dynamics prerun: T 2000/2000, 100.000%
# PREDICTION:
# SEQUENCE PREDICTED...00, 100.000%
#
# IC 8/10, 80.000%
# PREDICTION - Dynamics prerun
# PREDICTION - Dynamics prerun: T 2000/2000, 100.000%
# PREDICTION:
# SEQUENCE PREDICTED...00, 100.000%
#
# IC 9/10, 90.000%
# PREDICTION - Dynamics prerun
# PREDICTION - Dynamics prerun: T 2000/2000, 100.000%
# PREDICTION:
# SEQUENCE PREDICTED...00, 100.000%
#
# IC 10/10, 100.000%
# PREDICTION - Dynamics prerun
# PREDICTION - Dynamics prerun: T 2000/2000, 100.000%
# PREDICTION:
# SEQUENCE PREDICTED...00, 100.000%
#
# TRAJECTORIES SHAPES:
# (10, 7000, 40)
# (10, 7000, 40)
# AVERAGE RMNSE ERROR: 1.4543478258971396
# AVG NUMBER OF ACCURATE 0.5 PREDICTIONS: 0.1927341672707957
# AVG NUMBER OF ACCURATE 1 PREDICTIONS: 0.5494614417807773
# POWER SPECTRUM MEAN ERROR: 0.5470022839939883
# TEMPORAL DISTANCE: 0.1533716927987152
# GEOMETRICAL DISTANCE: 14.698544070514615
# IC INDEXES OF TEST PREDICTED...
