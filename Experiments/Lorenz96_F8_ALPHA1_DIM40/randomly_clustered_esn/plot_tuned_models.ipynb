# %%
# !bash ./2_Randomly_Clustered_ESN_Plot_Tuned_Model.sh "plot_tuned_model" 500 0.1 0.1 2 "grid_search.json"
# Out:
# {'radius': 0.1, 'sigma_input': 0.1}
# CUDA Device available? True
# Using device: cuda
# DEVICE NAME: NVIDIA GeForce RTX 4090
# MEMORY USAGE:
# Memory allocated: 0.0 GB
# Max memory allocated: 0.0 GB
# Memory cached:    0.0 GB
# MAX memory cached:    0.0 GB
# USING CUDA AND GPU.
# # GPU MEMORY nvidia-smi in MB={0: 1299}
# RANDOM SEED: 0
# TEST ON TRAINING SET
# IC 1/10, 10.000%
# PREDICTION - Dynamics prerun
# PREDICTION - Dynamics prerun: T 2000/2000, 100.000%
# PREDICTION:
# SEQUENCE PREDICTED...00, 100.000%
#
# IC 2/10, 20.000%
# PREDICTION - Dynamics prerun
# PREDICTION - Dynamics prerun: T 2000/2000, 100.000%
# PREDICTION:
# SEQUENCE PREDICTED...00, 100.000%
#
# IC 3/10, 30.000%
# PREDICTION - Dynamics prerun
# PREDICTION - Dynamics prerun: T 2000/2000, 100.000%
# PREDICTION:
# SEQUENCE PREDICTED...00, 100.000%
#
# IC 4/10, 40.000%
# PREDICTION - Dynamics prerun
# PREDICTION - Dynamics prerun: T 2000/2000, 100.000%
# PREDICTION:
# SEQUENCE PREDICTED...00, 100.000%
#
# ...

# %%
# !bash ./2_Randomly_Clustered_ESN_Plot_Tuned_Model.sh "plot_tuned_model" 3000 0.1 0.1 7 "grid_search.json" 100000 200
# Out:
# {'radius': 0.1, 'sigma_input': 0.1}
# CUDA Device available? True
# Using device: cuda
# DEVICE NAME: NVIDIA GeForce RTX 4090
# MEMORY USAGE:
# Memory allocated: 0.0 GB
# Max memory allocated: 0.0 GB
# Memory cached:    0.0 GB
# MAX memory cached:    0.0 GB
# USING CUDA AND GPU.
# # GPU MEMORY nvidia-smi in MB={0: 14}
# RANDOM SEED: 0
# TEST ON TRAINING SET
# IC 1/10, 10.000%
# PREDICTION - Dynamics prerun
# PREDICTION - Dynamics prerun: T 2000/2000, 100.000%
# PREDICTION:
# SEQUENCE PREDICTED...00, 100.000%
#
# IC 2/10, 20.000%
# PREDICTION - Dynamics prerun
# PREDICTION - Dynamics prerun: T 2000/2000, 100.000%
# PREDICTION:
# SEQUENCE PREDICTED...00, 100.000%
#
# IC 3/10, 30.000%
# PREDICTION - Dynamics prerun
# PREDICTION - Dynamics prerun: T 2000/2000, 100.000%
# PREDICTION:
# SEQUENCE PREDICTED...00, 100.000%
#
# IC 4/10, 40.000%
# PREDICTION - Dynamics prerun
# PREDICTION - Dynamics prerun: T 2000/2000, 100.000%
# PREDICTION:
# SEQUENCE PREDICTED...00, 100.000%
#
# ...

# %%
# !bash ./2_Randomly_Clustered_ESN_Plot_Tuned_Model.sh "plot_tuned_model" 3000 0.1 0.1 7 "grid_search.json" 100000 140
# Out:
# {'radius': 0.1, 'sigma_input': 0.1}
# CUDA Device available? True
# Using device: cuda
# DEVICE NAME: NVIDIA GeForce RTX 4090
# MEMORY USAGE:
# Memory allocated: 0.0 GB
# Max memory allocated: 0.0 GB
# Memory cached:    0.0 GB
# MAX memory cached:    0.0 GB
# USING CUDA AND GPU.
# # GPU MEMORY nvidia-smi in MB={0: 4123}
# RANDOM SEED: 0
# TEST ON TRAINING SET
# IC 1/10, 10.000%
# PREDICTION - Dynamics prerun
# PREDICTION - Dynamics prerun: T 2000/2000, 100.000%
# PREDICTION:
# SEQUENCE PREDICTED...00, 100.000%
#
# IC 2/10, 20.000%
# PREDICTION - Dynamics prerun
# PREDICTION - Dynamics prerun: T 2000/2000, 100.000%
# PREDICTION:
# SEQUENCE PREDICTED...00, 100.000%00, 26.114%
#
# IC 3/10, 30.000%
# PREDICTION - Dynamics prerun
# PREDICTION - Dynamics prerun: T 2000/2000, 100.000%
# PREDICTION:
# SEQUENCE PREDICTED...00, 100.000%
#
# IC 4/10, 40.000%
# PREDICTION - Dynamics prerun
# PREDICTION - Dynamics prerun: T 2000/2000, 100.000%
# PREDICTION:
# SEQUENCE PREDICTED...00, 100.000%
#
# ...

# %%
# !bash ./2_Randomly_Clustered_ESN_Plot_Tuned_Model.sh "plot_tuned_model" 3000 0.1 0.1 7 "grid_search.json" 10000
# Out:
# {'radius': 0.1, 'sigma_input': 0.1}
# CUDA Device available? True
# Using device: cuda
# DEVICE NAME: NVIDIA GeForce RTX 4090
# MEMORY USAGE:
# Memory allocated: 0.0 GB
# Max memory allocated: 0.0 GB
# Memory cached:    0.0 GB
# MAX memory cached:    0.0 GB
# USING CUDA AND GPU.
# # GPU MEMORY nvidia-smi in MB={0: 14}
# RANDOM SEED: 0
# TEST ON TRAINING SET
# IC 1/1, 100.000%
# PREDICTION - Dynamics prerun
# PREDICTION - Dynamics prerun: T 2000/2000, 100.000%
# PREDICTION:
# SEQUENCE PREDICTED...00, 100.000%
#
# TRAJECTORIES SHAPES:
# (1, 7000, 40)
# (1, 7000, 40)
# AVERAGE RMNSE ERROR: 1.6547532548763495
# AVG NUMBER OF ACCURATE 0.5 PREDICTIONS: 2.6205084146467836
# AVG NUMBER OF ACCURATE 1 PREDICTIONS: 3.043171062170458
# POWER SPECTRUM MEAN ERROR: 1.8198114007733288
# TEMPORAL DISTANCE: 0.23077891785406743
# GEOMETRICAL DISTANCE: 19.08691127908919
# IC INDEXES OF TRAIN PREDICTED...
#
#
# TEST ON TESTING SET
# IC 1/1, 100.000%
# PREDICTION - Dynamics prerun
# ...
