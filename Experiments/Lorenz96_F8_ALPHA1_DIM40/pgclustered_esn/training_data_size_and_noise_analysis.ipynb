# %% [markdown]
# # Analyse the training data

# %%
# !bash ./1_PGClustered_ESN_Evaluate_Tuned_Model.sh "evaluate_tuned_model" 3000 1 1 7 "grid_search.json" 10000
# Out:
# {'radius': 0.9, 'sigma_input': 0.1, 'regularization': 0.01, 'in_cluster_weight': 0.5, 'noise_level': 5}
# AVERAGE RMNSE ERROR ON TRAIN DATA SET: 1.3876799326442526 ± 0.016856484386676193
# AVG NUMBER OF ACCURATE 0.5 PREDICTIONS ON TRAIN DATA SET: 2.9704730867963867 ± 0.18689910964149006
# AVG NUMBER OF ACCURATE 1 PREDICTIONS ON TRAIN DATA SET: 4.618857412138718 ± 0.6845694554555997
# POWER SPECTRUM MEAN ERROR ON TRAIN DATA SET: 1.8247152356775491 ± 1.147024703778426
# TEMPORAL DISTANCE ON TRAIN DATA SET: 0.2029953532344914 ± 0.007497462159749194
# GEOMETRICAL DISTANCE ON TRAIN DATA SET: 13.644764895436584 ± 0.37049326893333534
#
#
# AVERAGE RMNSE ERROR ON TEST DATA SET: 1.4017647191576346 ± 0.029699537962156422
# AVG NUMBER OF ACCURATE 0.5 PREDICTIONS ON TEST DATA SET: 1.1699302083455319 ± 0.18823251468036684
# AVG NUMBER OF ACCURATE 1 PREDICTIONS ON TEST DATA SET: 2.1336010446995104 ± 0.3817128123617785
# ...

# %%
# !bash ./1_PGClustered_ESN_Evaluate_Tuned_Model.sh "evaluate_tuned_model" 3000 1 1 7 "grid_search.json" 20000
# Out:
# {'radius': 0.9, 'sigma_input': 0.1, 'regularization': 0.01, 'in_cluster_weight': 0.5, 'noise_level': 5}
# AVERAGE RMNSE ERROR ON TRAIN DATA SET: 1.392797409533621 ± 0.009725953679525544
# AVG NUMBER OF ACCURATE 0.5 PREDICTIONS ON TRAIN DATA SET: 2.5790874751894637 ± 0.059946617444301215
# AVG NUMBER OF ACCURATE 1 PREDICTIONS ON TRAIN DATA SET: 3.6475786481293135 ± 0.33420296621113477
# POWER SPECTRUM MEAN ERROR ON TRAIN DATA SET: 1.1116517849799963 ± 0.729594603504251
# TEMPORAL DISTANCE ON TRAIN DATA SET: 0.15715823077810126 ± 0.004482595972657044
# GEOMETRICAL DISTANCE ON TRAIN DATA SET: 13.301046015898015 ± 0.1134191133701851
#
#
# AVERAGE RMNSE ERROR ON TEST DATA SET: 1.409226795735784 ± 0.009472441653763068
# AVG NUMBER OF ACCURATE 0.5 PREDICTIONS ON TEST DATA SET: 1.520740205790182 ± 0.2814425483834723
# AVG NUMBER OF ACCURATE 1 PREDICTIONS ON TEST DATA SET: 2.4370728256215086 ± 0.48216231470388177
# ...

# %%
# !bash ./1_PGClustered_ESN_Evaluate_Tuned_Model.sh "evaluate_tuned_model" 3000 1 1 7 "grid_search.json" 30000
# Out:
# {'radius': 0.9, 'sigma_input': 0.1, 'regularization': 0.01, 'in_cluster_weight': 0.5, 'noise_level': 5}
# AVERAGE RMNSE ERROR ON TRAIN DATA SET: 1.3683767736724275 ± 0.014486468423519958
# AVG NUMBER OF ACCURATE 0.5 PREDICTIONS ON TRAIN DATA SET: 2.479057315275527 ± 0.26052176498454466
# AVG NUMBER OF ACCURATE 1 PREDICTIONS ON TRAIN DATA SET: 4.435140048015095 ± 0.3547323553384666
# POWER SPECTRUM MEAN ERROR ON TRAIN DATA SET: 0.951922548946426 ± 0.4402390320215394
# TEMPORAL DISTANCE ON TRAIN DATA SET: 0.13853335911688872 ± 0.0024337600956848247
# GEOMETRICAL DISTANCE ON TRAIN DATA SET: 13.128487388522458 ± 0.22106479467028758
#
#
# AVERAGE RMNSE ERROR ON TEST DATA SET: 1.3864668247391427 ± 0.01359584285285859
# AVG NUMBER OF ACCURATE 0.5 PREDICTIONS ON TEST DATA SET: 1.815758733761707 ± 0.2360165447784131
# AVG NUMBER OF ACCURATE 1 PREDICTIONS ON TEST DATA SET: 3.000341247221393 ± 0.6664690539548576
# ...

# %%
# !bash ./1_PGClustered_ESN_Evaluate_Tuned_Model.sh "evaluate_tuned_model" 3000 1 1 7 "grid_search.json" 40000
# Out:
# {'radius': 0.9, 'sigma_input': 0.1, 'regularization': 0.01, 'in_cluster_weight': 0.5, 'noise_level': 5}
# AVERAGE RMNSE ERROR ON TRAIN DATA SET: 1.3800843363754314 ± 0.011605145561996733
# AVG NUMBER OF ACCURATE 0.5 PREDICTIONS ON TRAIN DATA SET: 2.4074864402948513 ± 0.1398894604104996
# AVG NUMBER OF ACCURATE 1 PREDICTIONS ON TRAIN DATA SET: 3.73464715351919 ± 0.3282902164049578
# POWER SPECTRUM MEAN ERROR ON TRAIN DATA SET: 0.5816459398827746 ± 0.38515745013735814
# TEMPORAL DISTANCE ON TRAIN DATA SET: 0.12356827397416899 ± 0.00290114277271978
# GEOMETRICAL DISTANCE ON TRAIN DATA SET: 13.235176341251915 ± 0.11806291572084972
#
#
# AVERAGE RMNSE ERROR ON TEST DATA SET: 1.3897840900211555 ± 0.009268514748472656
# AVG NUMBER OF ACCURATE 0.5 PREDICTIONS ON TEST DATA SET: 1.9161833788133318 ± 0.1823211266997844
# AVG NUMBER OF ACCURATE 1 PREDICTIONS ON TEST DATA SET: 3.0266026863875304 ± 0.38781460915326943
# ...

# %%
# !bash ./1_PGClustered_ESN_Evaluate_Tuned_Model.sh "evaluate_tuned_model" 3000 1 1 7 "grid_search.json" 50000
# Out:
# {'radius': 0.9, 'sigma_input': 0.1, 'regularization': 0.01, 'in_cluster_weight': 0.5, 'noise_level': 5}
# AVERAGE RMNSE ERROR ON TRAIN DATA SET: 1.3740949690125033 ± 0.009721083134325867
# AVG NUMBER OF ACCURATE 0.5 PREDICTIONS ON TRAIN DATA SET: 2.6416415470229673 ± 0.11416760631256784
# AVG NUMBER OF ACCURATE 1 PREDICTIONS ON TRAIN DATA SET: 3.8414399157935053 ± 0.20372963169780522
# POWER SPECTRUM MEAN ERROR ON TRAIN DATA SET: 0.477778016507674 ± 0.3342095323102424
# TEMPORAL DISTANCE ON TRAIN DATA SET: 0.11635361432361002 ± 0.0019278545881559026
# GEOMETRICAL DISTANCE ON TRAIN DATA SET: 13.134170525547471 ± 0.12531228206733186
#
#
# AVERAGE RMNSE ERROR ON TEST DATA SET: 1.387851217822609 ± 0.01467324078226339
# AVG NUMBER OF ACCURATE 0.5 PREDICTIONS ON TEST DATA SET: 2.0335708847855742 ± 0.2053753907824022
# AVG NUMBER OF ACCURATE 1 PREDICTIONS ON TEST DATA SET: 3.1479913987563295 ± 0.3616104491612395
# ...

# %%
# !bash ./1_PGClustered_ESN_Evaluate_Tuned_Model.sh "evaluate_tuned_model" 3000 1 1 7 "grid_search.json" 60000
# Out:
# {'radius': 0.9, 'sigma_input': 0.1, 'regularization': 0.01, 'in_cluster_weight': 0.5, 'noise_level': 5}
# AVERAGE RMNSE ERROR ON TRAIN DATA SET: 1.369366323874496 ± 0.008526486995392967
# AVG NUMBER OF ACCURATE 0.5 PREDICTIONS ON TRAIN DATA SET: 2.771821642460259 ± 0.08361459427581025
# AVG NUMBER OF ACCURATE 1 PREDICTIONS ON TRAIN DATA SET: 4.1188475001182105 ± 0.1728581717440534
# POWER SPECTRUM MEAN ERROR ON TRAIN DATA SET: 0.3387619547440226 ± 0.2270631188752163
# TEMPORAL DISTANCE ON TRAIN DATA SET: 0.11163133218528491 ± 0.001901511892041664
# GEOMETRICAL DISTANCE ON TRAIN DATA SET: 13.171453041527906 ± 0.07007828379855116
#
#
# AVERAGE RMNSE ERROR ON TEST DATA SET: 1.383181713374438 ± 0.0073759463349410935
# AVG NUMBER OF ACCURATE 0.5 PREDICTIONS ON TEST DATA SET: 2.1445902735351257 ± 0.18065256205612984
# AVG NUMBER OF ACCURATE 1 PREDICTIONS ON TEST DATA SET: 3.3865844632834436 ± 0.22958646350416378
# ...

# %%
# !bash ./1_PGClustered_ESN_Evaluate_Tuned_Model.sh "evaluate_tuned_model" 3000 1 1 7 "grid_search.json" 70000
# Out:
# {'radius': 0.9, 'sigma_input': 0.1, 'regularization': 0.01, 'in_cluster_weight': 0.5, 'noise_level': 5}
# AVERAGE RMNSE ERROR ON TRAIN DATA SET: 1.3693946573157125 ± 0.008903277357287808
# AVG NUMBER OF ACCURATE 0.5 PREDICTIONS ON TRAIN DATA SET: 2.789009923459555 ± 0.04498254077154436
# AVG NUMBER OF ACCURATE 1 PREDICTIONS ON TRAIN DATA SET: 4.214604071040519 ± 0.1585641502136567
# POWER SPECTRUM MEAN ERROR ON TRAIN DATA SET: 0.4621811663766106 ± 0.16237678792030788
# TEMPORAL DISTANCE ON TRAIN DATA SET: 0.10948314233047862 ± 0.0015064042588528886
# GEOMETRICAL DISTANCE ON TRAIN DATA SET: 13.136186362434795 ± 0.11744177670412041
#
#
# AVERAGE RMNSE ERROR ON TEST DATA SET: 1.3769589168546454 ± 0.005866608336824756
# AVG NUMBER OF ACCURATE 0.5 PREDICTIONS ON TEST DATA SET: 2.2842567972835046 ± 0.1510576186168684
# AVG NUMBER OF ACCURATE 1 PREDICTIONS ON TEST DATA SET: 3.6253184153597324 ± 0.19473891806701016
# ...

# %%
# !bash ./1_PGClustered_ESN_Evaluate_Tuned_Model.sh "evaluate_tuned_model" 3000 1 1 7 "grid_search.json" 80000
# Out:
# {'radius': 0.9, 'sigma_input': 0.1, 'regularization': 0.01, 'in_cluster_weight': 0.5, 'noise_level': 5}
# AVERAGE RMNSE ERROR ON TRAIN DATA SET: 1.3659136330409523 ± 0.003808023715452782
# AVG NUMBER OF ACCURATE 0.5 PREDICTIONS ON TRAIN DATA SET: 2.757112982326435 ± 0.10349709448155509
# AVG NUMBER OF ACCURATE 1 PREDICTIONS ON TRAIN DATA SET: 4.2124250102799525 ± 0.20134250250400207
# POWER SPECTRUM MEAN ERROR ON TRAIN DATA SET: 0.42091829627095095 ± 0.3752193729535781
# TEMPORAL DISTANCE ON TRAIN DATA SET: 0.10794426974771601 ± 0.0007226331047387491
# GEOMETRICAL DISTANCE ON TRAIN DATA SET: 13.056149549786738 ± 0.059396297722024385
#
#
# AVERAGE RMNSE ERROR ON TEST DATA SET: 1.376896716432504 ± 0.006433393281917516
# AVG NUMBER OF ACCURATE 0.5 PREDICTIONS ON TEST DATA SET: 2.280687646037749 ± 0.17820291297143068
# AVG NUMBER OF ACCURATE 1 PREDICTIONS ON TEST DATA SET: 3.7480032931809384 ± 0.1988703169683876
# ...

# %%
# !bash ./1_PGClustered_ESN_Evaluate_Tuned_Model.sh "evaluate_tuned_model" 3000 1 1 7 "grid_search.json" 90000
# Out:
# {'radius': 0.9, 'sigma_input': 0.1, 'regularization': 0.01, 'in_cluster_weight': 0.5, 'noise_level': 5}
# AVERAGE RMNSE ERROR ON TRAIN DATA SET: 1.367328431698008 ± 0.008607434977321788
# AVG NUMBER OF ACCURATE 0.5 PREDICTIONS ON TRAIN DATA SET: 2.7288791174718536 ± 0.12032028980250174
# AVG NUMBER OF ACCURATE 1 PREDICTIONS ON TRAIN DATA SET: 4.373882141633996 ± 0.19505221305452325
# POWER SPECTRUM MEAN ERROR ON TRAIN DATA SET: 0.38247897428170485 ± 0.2794435817447484
# TEMPORAL DISTANCE ON TRAIN DATA SET: 0.10822977461117714 ± 0.0017138168022310602
# GEOMETRICAL DISTANCE ON TRAIN DATA SET: 12.966737078866043 ± 0.12976584800748026
#
#
# AVERAGE RMNSE ERROR ON TEST DATA SET: 1.3742428713019588 ± 0.007429823859187154
# AVG NUMBER OF ACCURATE 0.5 PREDICTIONS ON TEST DATA SET: 2.352878426234793 ± 0.1783056168690296
# AVG NUMBER OF ACCURATE 1 PREDICTIONS ON TEST DATA SET: 3.889679812630874 ± 0.29129772295514655
# ...

# %% [markdown]
# # Analyse the noise degree

# %%
# !bash ./1_PGClustered_ESN_Evaluate_Tuned_Model.sh "evaluate_tuned_model" 3000 1 1 7 "grid_search.json" 100000 0
# Out:
# {'radius': 0.9, 'sigma_input': 0.1, 'regularization': 0.01, 'in_cluster_weight': 0.5, 'noise_level': 5}
# AVERAGE RMNSE ERROR ON TRAIN DATA SET: 1.36340879771322 ± 0.004496453793308694
# AVG NUMBER OF ACCURATE 0.5 PREDICTIONS ON TRAIN DATA SET: 2.821019574632015 ± 0.15195591580663023
# AVG NUMBER OF ACCURATE 1 PREDICTIONS ON TRAIN DATA SET: 4.500173740714071 ± 0.27613225863106083
# POWER SPECTRUM MEAN ERROR ON TRAIN DATA SET: 0.4127101549978649 ± 0.21688447242812467
# TEMPORAL DISTANCE ON TRAIN DATA SET: 0.10752459695324997 ± 0.0016631021198932102
# GEOMETRICAL DISTANCE ON TRAIN DATA SET: 13.069065411698526 ± 0.06638745093848421
#
#
# AVERAGE RMNSE ERROR ON TEST DATA SET: 1.3726891449906906 ± 0.005807830739870264
# AVG NUMBER OF ACCURATE 0.5 PREDICTIONS ON TEST DATA SET: 2.309428706069359 ± 0.18199443302838197
# AVG NUMBER OF ACCURATE 1 PREDICTIONS ON TEST DATA SET: 3.870913591080823 ± 0.1774735443280065
# ...

# %%
# !bash ./1_PGClustered_ESN_Evaluate_Tuned_Model.sh "evaluate_tuned_model" 3000 1 1 7 "grid_search.json" 100000 20
# Out:
# {'radius': 0.9, 'sigma_input': 0.1, 'regularization': 0.01, 'in_cluster_weight': 0.5, 'noise_level': 5}
# AVERAGE RMNSE ERROR ON TRAIN DATA SET: 1.3627903171707283 ± 0.010714710029805032
# AVG NUMBER OF ACCURATE 0.5 PREDICTIONS ON TRAIN DATA SET: 2.397511601813293 ± 0.0771146118171701
# AVG NUMBER OF ACCURATE 1 PREDICTIONS ON TRAIN DATA SET: 3.9079388390038963 ± 0.1632703737520713
# POWER SPECTRUM MEAN ERROR ON TRAIN DATA SET: 0.38970521642565537 ± 0.23431842611728074
# TEMPORAL DISTANCE ON TRAIN DATA SET: 0.10718094636486449 ± 0.0012326718152555218
# GEOMETRICAL DISTANCE ON TRAIN DATA SET: 12.859600075654456 ± 0.11277594092105897
#
#
# AVERAGE RMNSE ERROR ON TEST DATA SET: 1.3678859398730125 ± 0.004776175240104388
# AVG NUMBER OF ACCURATE 0.5 PREDICTIONS ON TEST DATA SET: 2.1019858786647396 ± 0.18945405166403703
# AVG NUMBER OF ACCURATE 1 PREDICTIONS ON TEST DATA SET: 3.4355710641314383 ± 0.2901714490370303
# ...

# %%
# !bash ./1_PGClustered_ESN_Evaluate_Tuned_Model.sh "evaluate_tuned_model" 3000 1 1 7 "grid_search.json" 100000 40
# Out:
# {'radius': 0.9, 'sigma_input': 0.1, 'regularization': 0.01, 'in_cluster_weight': 0.5, 'noise_level': 5}
# AVERAGE RMNSE ERROR ON TRAIN DATA SET: 1.3516073355422975 ± 0.004752319163051096
# AVG NUMBER OF ACCURATE 0.5 PREDICTIONS ON TRAIN DATA SET: 2.1799248708681054 ± 0.10939750451565705
# AVG NUMBER OF ACCURATE 1 PREDICTIONS ON TRAIN DATA SET: 3.7569637413084402 ± 0.18967231073634477
# POWER SPECTRUM MEAN ERROR ON TRAIN DATA SET: 0.47005246898862935 ± 0.28582561688469876
# TEMPORAL DISTANCE ON TRAIN DATA SET: 0.10938003918461314 ± 0.001668104629589368
# GEOMETRICAL DISTANCE ON TRAIN DATA SET: 12.608435636891384 ± 0.08317060210557407
#
#
# AVERAGE RMNSE ERROR ON TEST DATA SET: 1.3581820664587634 ± 0.005919349049263499
# AVG NUMBER OF ACCURATE 0.5 PREDICTIONS ON TEST DATA SET: 1.9058704102137543 ± 0.13071921879514017
# AVG NUMBER OF ACCURATE 1 PREDICTIONS ON TEST DATA SET: 3.170646116663599 ± 0.1976546249757315
# ...

# %%
# !bash ./1_PGClustered_ESN_Evaluate_Tuned_Model.sh "evaluate_tuned_model" 3000 1 1 7 "grid_search.json" 100000 60
# Out:
# {'radius': 0.9, 'sigma_input': 0.1, 'regularization': 0.01, 'in_cluster_weight': 0.5, 'noise_level': 5}
# AVERAGE RMNSE ERROR ON TRAIN DATA SET: 1.3341417469319616 ± 0.0064989012284132775
# AVG NUMBER OF ACCURATE 0.5 PREDICTIONS ON TRAIN DATA SET: 1.9351186654223926 ± 0.12218901550813896
# AVG NUMBER OF ACCURATE 1 PREDICTIONS ON TRAIN DATA SET: 3.516891357514993 ± 0.21912005679083488
# POWER SPECTRUM MEAN ERROR ON TRAIN DATA SET: 0.5879985961885431 ± 0.37013368623001797
# TEMPORAL DISTANCE ON TRAIN DATA SET: 0.1145977485525683 ± 0.001875196246175651
# GEOMETRICAL DISTANCE ON TRAIN DATA SET: 12.246634622916753 ± 0.08579577531309258
#
#
# AVERAGE RMNSE ERROR ON TEST DATA SET: 1.3402739516460893 ± 0.008386104259179863
# AVG NUMBER OF ACCURATE 0.5 PREDICTIONS ON TEST DATA SET: 1.6177835496616175 ± 0.08885957212728375
# AVG NUMBER OF ACCURATE 1 PREDICTIONS ON TEST DATA SET: 3.044016387465506 ± 0.22638341696312855
# ...

# %%
# !bash ./1_PGClustered_ESN_Evaluate_Tuned_Model.sh "evaluate_tuned_model" 3000 1 1 7 "grid_search.json" 100000 80
# Out:
# {'radius': 0.9, 'sigma_input': 0.1, 'regularization': 0.01, 'in_cluster_weight': 0.5, 'noise_level': 5}
# AVERAGE RMNSE ERROR ON TRAIN DATA SET: 1.3252776458361712 ± 0.0050992126889150054
# AVG NUMBER OF ACCURATE 0.5 PREDICTIONS ON TRAIN DATA SET: 1.7188844549492805 ± 0.11138821614392788
# AVG NUMBER OF ACCURATE 1 PREDICTIONS ON TRAIN DATA SET: 3.334977354020803 ± 0.15639605420135103
# POWER SPECTRUM MEAN ERROR ON TRAIN DATA SET: 0.8714914025804703 ± 0.2896563056431494
# TEMPORAL DISTANCE ON TRAIN DATA SET: 0.11997509248719651 ± 0.0026394430162379645
# GEOMETRICAL DISTANCE ON TRAIN DATA SET: 11.983382576117238 ± 0.08588951821675819
#
#
# AVERAGE RMNSE ERROR ON TEST DATA SET: 1.330898958069337 ± 0.00738311133534373
# AVG NUMBER OF ACCURATE 0.5 PREDICTIONS ON TEST DATA SET: 1.4404343027606836 ± 0.08403060681503131
# AVG NUMBER OF ACCURATE 1 PREDICTIONS ON TEST DATA SET: 2.8519584804307483 ± 0.18983296074877512
# ...

# %%
# !bash ./1_PGClustered_ESN_Evaluate_Tuned_Model.sh "evaluate_tuned_model" 3000 1 1 7 "grid_search.json" 100000 100
# Out:
# {'radius': 0.9, 'sigma_input': 0.1, 'regularization': 0.01, 'in_cluster_weight': 0.5, 'noise_level': 5}
# AVERAGE RMNSE ERROR ON TRAIN DATA SET: 1.3099046510059715 ± 0.005080072363252718
# AVG NUMBER OF ACCURATE 0.5 PREDICTIONS ON TRAIN DATA SET: 1.4999452035320169 ± 0.08364808809989155
# AVG NUMBER OF ACCURATE 1 PREDICTIONS ON TRAIN DATA SET: 3.193131769511858 ± 0.2055083675190368
# POWER SPECTRUM MEAN ERROR ON TRAIN DATA SET: 0.907934742280521 ± 0.3440156368392736
# TEMPORAL DISTANCE ON TRAIN DATA SET: 0.1298717007601066 ± 0.003459186061883259
# GEOMETRICAL DISTANCE ON TRAIN DATA SET: 11.782842176128696 ± 0.10798597724245358
#
#
# AVERAGE RMNSE ERROR ON TEST DATA SET: 1.3164460953596273 ± 0.007042279985285554
# AVG NUMBER OF ACCURATE 0.5 PREDICTIONS ON TEST DATA SET: 1.2972361977796625 ± 0.07382569954176865
# AVG NUMBER OF ACCURATE 1 PREDICTIONS ON TEST DATA SET: 2.8074943699112573 ± 0.20457458969123837
# ...

# %%
# !bash ./1_PGClustered_ESN_Evaluate_Tuned_Model.sh "evaluate_tuned_model" 3000 1 1 7 "grid_search.json" 100000 120
# Out:
# {'radius': 0.9, 'sigma_input': 0.1, 'regularization': 0.01, 'in_cluster_weight': 0.5, 'noise_level': 5}
# AVERAGE RMNSE ERROR ON TRAIN DATA SET: 1.2997894228316942 ± 0.007191478109372242
# AVG NUMBER OF ACCURATE 0.5 PREDICTIONS ON TRAIN DATA SET: 1.3515060817217024 ± 0.08416723595925792
# AVG NUMBER OF ACCURATE 1 PREDICTIONS ON TRAIN DATA SET: 3.0763078137363142 ± 0.26086492073612133
# POWER SPECTRUM MEAN ERROR ON TRAIN DATA SET: 1.2149508112306218 ± 0.39968507992692914
# TEMPORAL DISTANCE ON TRAIN DATA SET: 0.14362691807504396 ± 0.007036406912464624
# GEOMETRICAL DISTANCE ON TRAIN DATA SET: 11.596524772808692 ± 0.09532770823047343
#
#
# AVERAGE RMNSE ERROR ON TEST DATA SET: 1.3083825978830066 ± 0.00547668841521518
# AVG NUMBER OF ACCURATE 0.5 PREDICTIONS ON TEST DATA SET: 1.1763546805878917 ± 0.061956289318454046
# AVG NUMBER OF ACCURATE 1 PREDICTIONS ON TEST DATA SET: 2.681879031067221 ± 0.157074178328116
# ...

# %%
# !bash ./1_PGClustered_ESN_Evaluate_Tuned_Model.sh "evaluate_tuned_model" 3000 1 1 7 "grid_search.json" 100000 140
# Out:
# {'radius': 0.9, 'sigma_input': 0.1, 'regularization': 0.01, 'in_cluster_weight': 0.5, 'noise_level': 5}
# AVERAGE RMNSE ERROR ON TRAIN DATA SET: 1.3016144993916037 ± 0.006810189171244091
# AVG NUMBER OF ACCURATE 0.5 PREDICTIONS ON TRAIN DATA SET: 1.2355274512412062 ± 0.08946976594067473
# AVG NUMBER OF ACCURATE 1 PREDICTIONS ON TRAIN DATA SET: 2.9723328024454907 ± 0.24748312502330191
# POWER SPECTRUM MEAN ERROR ON TRAIN DATA SET: 1.234454355144106 ± 0.41186843970574316
# TEMPORAL DISTANCE ON TRAIN DATA SET: 0.17969844798689769 ± 0.01704374844449793
# GEOMETRICAL DISTANCE ON TRAIN DATA SET: 11.759391850763585 ± 0.18420605369212506
#
#
# AVERAGE RMNSE ERROR ON TEST DATA SET: 1.30721368311135 ± 0.008090017714818525
# AVG NUMBER OF ACCURATE 0.5 PREDICTIONS ON TEST DATA SET: 1.0517537320979122 ± 0.07292742381082121
# AVG NUMBER OF ACCURATE 1 PREDICTIONS ON TEST DATA SET: 2.6086738605161206 ± 0.13089828757424324
# ...

# %%
# !bash ./1_PGClustered_ESN_Evaluate_Tuned_Model.sh "evaluate_tuned_model" 3000 1 1 7 "grid_search.json" 100000 160
# Out:
# {'radius': 0.9, 'sigma_input': 0.1, 'regularization': 0.01, 'in_cluster_weight': 0.5, 'noise_level': 5}
# AVERAGE RMNSE ERROR ON TRAIN DATA SET: 1.2948829333108232 ± 0.007075702494089796
# AVG NUMBER OF ACCURATE 0.5 PREDICTIONS ON TRAIN DATA SET: 1.1224229267638708 ± 0.08888208580939605
# AVG NUMBER OF ACCURATE 1 PREDICTIONS ON TRAIN DATA SET: 2.8896599885898597 ± 0.28072009596092273
# POWER SPECTRUM MEAN ERROR ON TRAIN DATA SET: 1.4451335566063024 ± 0.4748519090693252
# TEMPORAL DISTANCE ON TRAIN DATA SET: 0.22850217715400417 ± 0.03420439134124878
# GEOMETRICAL DISTANCE ON TRAIN DATA SET: 12.196617615633574 ± 0.3915808386939173
#
#
# AVERAGE RMNSE ERROR ON TEST DATA SET: 1.304688997192543 ± 0.007724836234403424
# AVG NUMBER OF ACCURATE 0.5 PREDICTIONS ON TEST DATA SET: 0.9312103450241602 ± 0.08388353339441953
# AVG NUMBER OF ACCURATE 1 PREDICTIONS ON TEST DATA SET: 2.5386809260862 ± 0.17577758497139684
# ...

# %%
# !bash ./1_PGClustered_ESN_Evaluate_Tuned_Model.sh "evaluate_tuned_model" 3000 1 1 7 "grid_search.json" 100000 180
# Out:
# {'radius': 0.9, 'sigma_input': 0.1, 'regularization': 0.01, 'in_cluster_weight': 0.5, 'noise_level': 5}
# AVERAGE RMNSE ERROR ON TRAIN DATA SET: 1.3002994459898127 ± 0.01241904702558998
# AVG NUMBER OF ACCURATE 0.5 PREDICTIONS ON TRAIN DATA SET: 1.0219982817122455 ± 0.07273040504169177
# AVG NUMBER OF ACCURATE 1 PREDICTIONS ON TRAIN DATA SET: 3.009188985309555 ± 0.3612722522442231
# POWER SPECTRUM MEAN ERROR ON TRAIN DATA SET: 1.2772008889146027 ± 0.9413974037306934
# TEMPORAL DISTANCE ON TRAIN DATA SET: 0.28100487097282467 ± 0.04351334385361218
# GEOMETRICAL DISTANCE ON TRAIN DATA SET: 12.969354517363561 ± 0.6340242477465219
#
#
# AVERAGE RMNSE ERROR ON TEST DATA SET: 1.307854699541927 ± 0.009160678036426628
# AVG NUMBER OF ACCURATE 0.5 PREDICTIONS ON TEST DATA SET: 0.8275734638513551 ± 0.06843794518363022
# AVG NUMBER OF ACCURATE 1 PREDICTIONS ON TEST DATA SET: 2.4773103096657625 ± 0.25152659480918504
# ...

# %%
# !bash ./1_PGClustered_ESN_Evaluate_Tuned_Model.sh "evaluate_tuned_model" 3000 1 1 7 "grid_search.json" 100000 200
# Out:
# {'radius': 0.9, 'sigma_input': 0.1, 'regularization': 0.01, 'in_cluster_weight': 0.5, 'noise_level': 5}
# AVERAGE RMNSE ERROR ON TRAIN DATA SET: 1.296055344069795 ± 0.005015382376532564
# AVG NUMBER OF ACCURATE 0.5 PREDICTIONS ON TRAIN DATA SET: 0.945919005157984 ± 0.0769208860439811
# AVG NUMBER OF ACCURATE 1 PREDICTIONS ON TRAIN DATA SET: 3.131084892855383 ± 0.49772018301486015
# POWER SPECTRUM MEAN ERROR ON TRAIN DATA SET: 1.7026199684177943 ± 0.6148065544009021
# TEMPORAL DISTANCE ON TRAIN DATA SET: 0.3329090643294488 ± 0.03026684734964869
# GEOMETRICAL DISTANCE ON TRAIN DATA SET: 13.778286950989989 ± 0.46519986957901743
#
#
# AVERAGE RMNSE ERROR ON TEST DATA SET: 1.3133293444557304 ± 0.007206449302876585
# AVG NUMBER OF ACCURATE 0.5 PREDICTIONS ON TEST DATA SET: 0.7492963415299707 ± 0.056856154544086206
# AVG NUMBER OF ACCURATE 1 PREDICTIONS ON TEST DATA SET: 2.396835341577255 ± 0.21942019956286557
# ...
