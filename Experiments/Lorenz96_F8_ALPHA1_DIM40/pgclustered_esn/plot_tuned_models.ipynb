# %%
# !bash ./2_PGClustered_ESN_Plot_Tuned_Model.sh "plot_tuned_model" 500 1 1 2 "grid_search.json"
# Out:
# {'radius': 0.4, 'sigma_input': 0.1, 'regularization': 0.01, 'in_cluster_weight': 0.5, 'noise_level': 5}
# CUDA Device available? True
# Using device: cuda
# DEVICE NAME: NVIDIA GeForce RTX 4090
# MEMORY USAGE:
# Memory allocated: 0.0 GB
# Max memory allocated: 0.0 GB
# Memory cached:    0.0 GB
# MAX memory cached:    0.0 GB
# USING CUDA AND GPU.
# # GPU MEMORY nvidia-smi in MB={0: 291}
# RANDOM SEED: 0
# TEST ON TRAINING SET
# IC 1/10, 10.000%
# PREDICTION - Dynamics prerun
# PREDICTION - Dynamics prerun: T 2000/2000, 100.000%
# PREDICTION:
# SEQUENCE PREDICTED...00, 100.000%
#
# IC 2/10, 20.000%
# PREDICTION - Dynamics prerun
# PREDICTION - Dynamics prerun: T 2000/2000, 100.000%
# PREDICTION:
# SEQUENCE PREDICTED...00, 100.000%
#
# IC 3/10, 30.000%
# PREDICTION - Dynamics prerun
# PREDICTION - Dynamics prerun: T 2000/2000, 100.000%
# PREDICTION:
# SEQUENCE PREDICTED...00, 100.000%
#
# IC 4/10, 40.000%
# PREDICTION - Dynamics prerun
# PREDICTION - Dynamics prerun: T 2000/2000, 100.000%
# PREDICTION:
# SEQUENCE PREDICTED...00, 100.000%
#
# IC 5/10, 50.000%
# PREDICTION - Dynamics prerun
# PREDICTION - Dynamics prerun: T 2000/2000, 100.000%
# PREDICTION:
# SEQUENCE PREDICTED...00, 100.000%
#
# IC 6/10, 60.000%
# PREDICTION - Dynamics prerun
# PREDICTION - Dynamics prerun: T 2000/2000, 100.000%
# PREDICTION:
# SEQUENCE PREDICTED...00, 100.000%
#
# IC 7/10, 70.000%
# PREDICTION - Dynamics prerun
# PREDICTION - Dynamics prerun: T 2000/2000, 100.000%
# PREDICTION:
# SEQUENCE PREDICTED...00, 100.000%
#
# IC 8/10, 80.000%
# PREDICTION - Dynamics prerun
# PREDICTION - Dynamics prerun: T 2000/2000, 100.000%
# PREDICTION:
# SEQUENCE PREDICTED...00, 100.000%
#
# IC 9/10, 90.000%
# PREDICTION - Dynamics prerun
# PREDICTION - Dynamics prerun: T 2000/2000, 100.000%
# PREDICTION:
# SEQUENCE PREDICTED...00, 100.000%
#
# IC 10/10, 100.000%
# PREDICTION - Dynamics prerun
# PREDICTION - Dynamics prerun: T 2000/2000, 100.000%
# PREDICTION:
# SEQUENCE PREDICTED...00, 100.000%
#
# TRAJECTORIES SHAPES:
# (10, 7000, 40)
# (10, 7000, 40)
# AVERAGE RMNSE ERROR: 1.390909895883456
# AVG NUMBER OF ACCURATE 0.5 PREDICTIONS: 1.641621722981953
# AVG NUMBER OF ACCURATE 1 PREDICTIONS: 2.804789328967106
# POWER SPECTRUM MEAN ERROR: 1.537324008720185
# TEMPORAL DISTANCE: 0.11218496712049811
# GEOMETRICAL DISTANCE: 13.383815802344134
# IC INDEXES OF TRAIN PREDICTED...
#
#
# TEST ON TESTING SET
# IC 1/10, 10.000%
# PREDICTION - Dynamics prerun
# PREDICTION - Dynamics prerun: T 2000/2000, 100.000%
# PREDICTION:
# SEQUENCE PREDICTED...00, 100.000%
#
# IC 2/10, 20.000%
# PREDICTION - Dynamics prerun
# PREDICTION - Dynamics prerun: T 2000/2000, 100.000%
# PREDICTION:
# SEQUENCE PREDICTED...00, 100.000%
#
# IC 3/10, 30.000%
# PREDICTION - Dynamics prerun
# PREDICTION - Dynamics prerun: T 2000/2000, 100.000%
# PREDICTION:
# SEQUENCE PREDICTED...00, 100.000%
#
# IC 4/10, 40.000%
# PREDICTION - Dynamics prerun
# PREDICTION - Dynamics prerun: T 2000/2000, 100.000%
# PREDICTION:
# SEQUENCE PREDICTED...00, 100.000%
#
# IC 5/10, 50.000%
# PREDICTION - Dynamics prerun
# PREDICTION - Dynamics prerun: T 2000/2000, 100.000%
# PREDICTION:
# SEQUENCE PREDICTED...00, 100.000%
#
# IC 6/10, 60.000%
# PREDICTION - Dynamics prerun
# PREDICTION - Dynamics prerun: T 2000/2000, 100.000%
# PREDICTION:
# SEQUENCE PREDICTED...00, 100.000%
#
# IC 7/10, 70.000%
# PREDICTION - Dynamics prerun
# PREDICTION - Dynamics prerun: T 2000/2000, 100.000%
# PREDICTION:
# SEQUENCE PREDICTED...00, 100.000%
#
# IC 8/10, 80.000%
# PREDICTION - Dynamics prerun
# PREDICTION - Dynamics prerun: T 2000/2000, 100.000%
# PREDICTION:
# SEQUENCE PREDICTED...00, 100.000%
#
# IC 9/10, 90.000%
# PREDICTION - Dynamics prerun
# PREDICTION - Dynamics prerun: T 2000/2000, 100.000%
# PREDICTION:
# SEQUENCE PREDICTED...00, 100.000%
#
# IC 10/10, 100.000%
# PREDICTION - Dynamics prerun
# PREDICTION - Dynamics prerun: T 2000/2000, 100.000%
# PREDICTION:
# SEQUENCE PREDICTED...00, 100.000%
#
# TRAJECTORIES SHAPES:
# (10, 7000, 40)
# (10, 7000, 40)
# AVERAGE RMNSE ERROR: 1.3988498184759686
# AVG NUMBER OF ACCURATE 0.5 PREDICTIONS: 1.6534562771126158
# AVG NUMBER OF ACCURATE 1 PREDICTIONS: 2.755760461854359
# POWER SPECTRUM MEAN ERROR: 0.9637927137861003
# TEMPORAL DISTANCE: 0.11427924917060764
# GEOMETRICAL DISTANCE: 13.49461325118132
# IC INDEXES OF TEST PREDICTED...
#
#
# /home/user/kuei_jan_CHU/PGClustered_ESN/Methods/./Utils/plotting_utils.py:206: RuntimeWarning: divide by zero encountered in log
#   plt.plot(np.log(np.arange(np.shape(error)[0])), np.log(error), label='log(error)')
# IC_IDX: 44000,
# VMIN: -7
# VMAX: 11
#
# /home/user/kuei_jan_CHU/PGClustered_ESN/Methods/./Utils/plotting_utils.py:206: RuntimeWarning: divide by zero encountered in log
#   plt.plot(np.log(np.arange(np.shape(error)[0])), np.log(error), label='log(error)')
# IC_IDX: 79000,
# VMIN: -9
# VMAX: 13
#
# /home/user/kuei_jan_CHU/PGClustered_ESN/Methods/./Utils/plotting_utils.py:206: RuntimeWarning: divide by zero encountered in log
#   plt.plot(np.log(np.arange(np.shape(error)[0])), np.log(error), label='log(error)')
# IC_IDX: 30000,
# VMIN: -7
# VMAX: 12
#
# /home/user/kuei_jan_CHU/PGClustered_ESN/Methods/./Utils/plotting_utils.py:206: RuntimeWarning: divide by zero encountered in log
#   plt.plot(np.log(np.arange(np.shape(error)[0])), np.log(error), label='log(error)')
# IC_IDX: 37000,
# VMIN: -7
# VMAX: 12
#
# /home/user/kuei_jan_CHU/PGClustered_ESN/Methods/./Utils/plotting_utils.py:206: RuntimeWarning: divide by zero encountered in log
#   plt.plot(np.log(np.arange(np.shape(error)[0])), np.log(error), label='log(error)')
# IC_IDX: 16000,
# VMIN: -6
# VMAX: 12
#
# /home/user/kuei_jan_CHU/PGClustered_ESN/Methods/./Utils/plotting_utils.py:206: RuntimeWarning: divide by zero encountered in log
#   plt.plot(np.log(np.arange(np.shape(error)[0])), np.log(error), label='log(error)')
# IC_IDX: 23000,
# VMIN: -7
# VMAX: 13

# %%
# !bash ./3_PGClustered_ESN_Train.sh
# Out:
# CUDA Device available? False
# Using device: cpu
# RANDOM SEED: 0
# Adding noise to the training data. 5 per mille
# ##Using 40/40 dimensions and 100000/100000 samples ##
# SCALING
# Initializing the input weights...
# Initializing the reservoir weights...
# NETWORK SPARSITY: 1.0
# Computing sparse hidden to hidden weight matrix...
# EIGENVALUE DECOMPOSITION
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
#
# TRAINING: Dynamics prerun...
# TRAINING - Dynamics prerun: T 2000/2000, 100.000%
# TRAINING: Teacher forcing...
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# TRAINING - Teacher forcing: T 97999/97999, 100.000%
# TEACHER FORCING ENDED.
#
# TRAINING: COMPUTING THE OUTPUT WEIGHTS...
# FINALISING WEIGHTS...
# COMPUTING NUMBER OF PARAMETERS...
# Number of trainable parameters: 20800
# Total number of parameters: 312000
# SAVING MODEL...
# Recording time...
# Total training time is 15.563007116317749
# MEMORY TRACKING IN MB...
# Script used 494.41796875 MB
# Saving the model... In path /Users/kuei_jan_chu/Desktop/new_pgc_esn/Results/Lorenz96_F8_ALPHA1_DIM40/pgclustered_esn/Trained_Models/RNN-pgclustered_esnLorenz96_F8_ALPHA1_DIM40-SS_1-RDIM_40-N_train_100000-N_test_100000-SIZE_500-SP_1.0-RADIUS_0.4-SIGMA_0.1-PIN_1.0-DL_2000-NL_5-IPL_7000-REG_0.01-ICW_0.5-WID_0/data.pickle

# %%
# !bash ./3_PGClustered_ESN_Test.sh
# Out:
# CUDA Device available? False
# Using device: cpu
# RANDOM SEED: 0
# TEST ON TESTING SET
# IC 1/10, 10.000%
# PREDICTION - Dynamics prerun
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# PREDICTION - Dynamics prerun: T 2000/2000, 100.000%
# PREDICTION:
# SEQUENCE PREDICTED...00, 100.000%
#
# IC 2/10, 20.000%
# PREDICTION - Dynamics prerun
# PREDICTION - Dynamics prerun: T 2000/2000, 100.000%
# PREDICTION:
# SEQUENCE PREDICTED...00, 100.000%
#
# IC 3/10, 30.000%
# PREDICTION - Dynamics prerun
# PREDICTION - Dynamics prerun: T 2000/2000, 100.000%
# PREDICTION:
# SEQUENCE PREDICTED...00, 100.000%
#
# IC 4/10, 40.000%
# PREDICTION - Dynamics prerun
# PREDICTION - Dynamics prerun: T 2000/2000, 100.000%
# PREDICTION:
# SEQUENCE PREDICTED...00, 100.000%
#
# IC 5/10, 50.000%
# PREDICTION - Dynamics prerun
# PREDICTION - Dynamics prerun: T 2000/2000, 100.000%
# PREDICTION:
# SEQUENCE PREDICTED...00, 100.000%
#
# IC 6/10, 60.000%
# PREDICTION - Dynamics prerun
# PREDICTION - Dynamics prerun: T 2000/2000, 100.000%
# PREDICTION:
# SEQUENCE PREDICTED...00, 100.000%
#
# IC 7/10, 70.000%
# PREDICTION - Dynamics prerun
# PREDICTION - Dynamics prerun: T 2000/2000, 100.000%
# PREDICTION:
# SEQUENCE PREDICTED...00, 100.000%
#
# IC 8/10, 80.000%
# PREDICTION - Dynamics prerun
# PREDICTION - Dynamics prerun: T 2000/2000, 100.000%
# PREDICTION:
# SEQUENCE PREDICTED...00, 100.000%
#
# IC 9/10, 90.000%
# PREDICTION - Dynamics prerun
# PREDICTION - Dynamics prerun: T 2000/2000, 100.000%
# PREDICTION:
# SEQUENCE PREDICTED...00, 100.000%
#
# IC 10/10, 100.000%
# PREDICTION - Dynamics prerun
# PREDICTION - Dynamics prerun: T 2000/2000, 100.000%
# PREDICTION:
# SEQUENCE PREDICTED...00, 100.000%
#
# TRAJECTORIES SHAPES:
# (10, 7000, 40)
# (10, 7000, 40)
# AVERAGE RMNSE ERROR: 1.3956240061721052
# AVG NUMBER OF ACCURATE 0.5 PREDICTIONS: 1.7024851442253621
# AVG NUMBER OF ACCURATE 1 PREDICTIONS: 2.7270194018227496
# POWER SPECTRUM MEAN ERROR: 0.4289054337393292
# TEMPORAL DISTANCE: 0.11137062422440598
# GEOMETRICAL DISTANCE: 13.460063703795882
# IC INDEXES OF TEST PREDICTED...
