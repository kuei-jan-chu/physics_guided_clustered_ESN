# %%
# !bash ./2_PGClustered_ESN_Plot_Tuned_Model.sh "plot_tuned_model" 500 1 1 2 "grid_search.json"
# Out:
# {'radius': 0.4, 'sigma_input': 0.1, 'regularization': 0.01, 'in_cluster_weight': 0.5, 'noise_level': 5}
# CUDA Device available? True
# Using device: cuda
# DEVICE NAME: NVIDIA GeForce RTX 4090
# MEMORY USAGE:
# Memory allocated: 0.0 GB
# Max memory allocated: 0.0 GB
# Memory cached:    0.0 GB
# MAX memory cached:    0.0 GB
# USING CUDA AND GPU.
# # GPU MEMORY nvidia-smi in MB={0: 14}
# RANDOM SEED: 0
# TEST ON TRAINING SET
# IC 1/10, 10.000%
# PREDICTION - Dynamics prerun
# PREDICTION - Dynamics prerun: T 2000/2000, 100.000%
# PREDICTION:
# SEQUENCE PREDICTED...00, 100.000%
#
# IC 2/10, 20.000%
# PREDICTION - Dynamics prerun
# PREDICTION - Dynamics prerun: T 2000/2000, 100.000%
# PREDICTION:
# SEQUENCE PREDICTED...00, 100.000%
#
# IC 3/10, 30.000%
# PREDICTION - Dynamics prerun
# PREDICTION - Dynamics prerun: T 2000/2000, 100.000%
# PREDICTION:
# SEQUENCE PREDICTED...00, 100.000%
#
# IC 4/10, 40.000%
# PREDICTION - Dynamics prerun
# ...

# %%
# !bash ./2_PGClustered_ESN_Plot_Tuned_Model.sh "plot_tuned_model" 3000 1 1 7 "grid_search.json" "-2 -1 1" 100000 200
# Out:
# {'radius': 0.9, 'sigma_input': 0.1, 'regularization': 0.01, 'in_cluster_weight': 0.5, 'noise_level': 5}
# CUDA Device available? True
# Using device: cuda
# DEVICE NAME: NVIDIA GeForce RTX 4090
# MEMORY USAGE:
# Memory allocated: 0.0 GB
# Max memory allocated: 0.0 GB
# Memory cached:    0.0 GB
# MAX memory cached:    0.0 GB
# USING CUDA AND GPU.
# # GPU MEMORY nvidia-smi in MB={0: 14}
# RANDOM SEED: 0
# TEST ON TRAINING SET
# IC 1/10, 10.000%
# PREDICTION - Dynamics prerun
# PREDICTION - Dynamics prerun: T 2000/2000, 100.000%
# PREDICTION:
# SEQUENCE PREDICTED...00, 100.000%
#
# IC 2/10, 20.000%
# PREDICTION - Dynamics prerun
# PREDICTION - Dynamics prerun: T 2000/2000, 100.000%
# PREDICTION:
# SEQUENCE PREDICTED...00, 100.000%
#
# IC 3/10, 30.000%
# PREDICTION - Dynamics prerun
# PREDICTION - Dynamics prerun: T 2000/2000, 100.000%
# PREDICTION:
# SEQUENCE PREDICTED...00, 100.000%
#
# IC 4/10, 40.000%
# PREDICTION - Dynamics prerun
# ...

# %%
# !bash ./2_PGClustered_ESN_Plot_Tuned_Model.sh "plot_tuned_model" 3000 1 1 7 "grid_search.json" "-2 -1 1" 100000 140
# Out:
# {'radius': 0.9, 'sigma_input': 0.1, 'regularization': 0.01, 'in_cluster_weight': 0.5, 'noise_level': 5}
# CUDA Device available? True
# Using device: cuda
# DEVICE NAME: NVIDIA GeForce RTX 4090
# MEMORY USAGE:
# Memory allocated: 0.0 GB
# Max memory allocated: 0.0 GB
# Memory cached:    0.0 GB
# MAX memory cached:    0.0 GB
# USING CUDA AND GPU.
# # GPU MEMORY nvidia-smi in MB={0: 14}
# RANDOM SEED: 0
# TEST ON TRAINING SET
# IC 1/10, 10.000%
# PREDICTION - Dynamics prerun
# PREDICTION - Dynamics prerun: T 2000/2000, 100.000%
# PREDICTION:
# SEQUENCE PREDICTED...00, 100.000%
#
# IC 2/10, 20.000%
# PREDICTION - Dynamics prerun
# PREDICTION - Dynamics prerun: T 2000/2000, 100.000%
# PREDICTION:
# SEQUENCE PREDICTED...00, 100.000%
#
# IC 3/10, 30.000%
# PREDICTION - Dynamics prerun
# PREDICTION - Dynamics prerun: T 2000/2000, 100.000%
# PREDICTION:
# SEQUENCE PREDICTED...00, 100.000%
#
# IC 4/10, 40.000%
# PREDICTION - Dynamics prerun
# ...

# %%
# !bash ./2_PGClustered_ESN_Plot_Tuned_Model.sh "plot_tuned_model" 3000 1 1 7 "grid_search.json" "-2 -1 1" 10000
# Out:
# {'radius': 0.9, 'sigma_input': 0.1, 'regularization': 0.01, 'in_cluster_weight': 0.5, 'noise_level': 5}
# CUDA Device available? True
# Using device: cuda
# DEVICE NAME: NVIDIA GeForce RTX 4090
# MEMORY USAGE:
# Memory allocated: 0.0 GB
# Max memory allocated: 0.0 GB
# Memory cached:    0.0 GB
# MAX memory cached:    0.0 GB
# USING CUDA AND GPU.
# # GPU MEMORY nvidia-smi in MB={0: 14}
# RANDOM SEED: 0
# TEST ON TRAINING SET
# IC 1/1, 100.000%
# PREDICTION - Dynamics prerun
# PREDICTION - Dynamics prerun: T 2000/2000, 100.000%
# PREDICTION:
# SEQUENCE PREDICTED...00, 100.000%
#
# TRAJECTORIES SHAPES:
# (1, 7000, 40)
# (1, 7000, 40)
# AVERAGE RMNSE ERROR: 1.3717414861873705
# AVG NUMBER OF ACCURATE 0.5 PREDICTIONS: 2.907919014962882
# AVG NUMBER OF ACCURATE 1 PREDICTIONS: 3.973028886722543
# POWER SPECTRUM MEAN ERROR: 3.3245956488096233
# TEMPORAL DISTANCE: 0.2087520612975764
# GEOMETRICAL DISTANCE: 13.460320242494586
# IC INDEXES OF TRAIN PREDICTED...
#
#
# TEST ON TESTING SET
# ...
