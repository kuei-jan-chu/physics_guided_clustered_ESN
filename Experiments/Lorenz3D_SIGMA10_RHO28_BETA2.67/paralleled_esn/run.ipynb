# %%
# !bash ./1_Paralleled_ESN_Train.sh
# Out:
# CUDA Device available? True
# Using device: cuda
# DEVICE NAME: NVIDIA GeForce RTX 4090
# MEMORY USAGE:
# Memory allocated: 0.0 GB
# Max memory allocated: 0.0 GB
# Memory cached:    0.0 GB
# MAX memory cached:    0.0 GB
# USING CUDA AND GPU.
# # GPU MEMORY nvidia-smi in MB={0: 14}
# Adding noise to the training data. 5 per mille
# ##Using 5/5 dimensions and 100000/100000 samples ##
# SCALING
# Initializing the reservoir weights...
# WEIGHT INIT
# EIGENVALUE DECOMPOSITION
# Initializing the input weights...
#
# TRAINING: Dynamics prerun...
# TRAINING - Dynamics prerun: T 2000/2000, 100.000%Dynamics prerun: T 1569/2000, 78.450%
# TRAINING: Teacher forcing...
# TRAINING - Teacher forcing: T 97999/97999, 100.000%Teacher forcing: T 2988/97999, 3.049% - Teacher forcing: T 13020/97999, 13.286%RAINING - Teacher forcing: T 22457/97999, 22.916%rcing: T 32493/97999, 33.156%%ING - Teacher forcing: T 51325/97999, 52.373%.271% 72.986% 81.346% T 87787/97999, 89.579%999, 97.979%
# ...

# %%
# !bash ./2_Paralleled_ESN_Test.sh
# Out:
# CUDA Device available? True
# Using device: cuda
# DEVICE NAME: NVIDIA GeForce RTX 4090
# MEMORY USAGE:
# Memory allocated: 0.0 GB
# Max memory allocated: 0.0 GB
# Memory cached:    0.0 GB
# MAX memory cached:    0.0 GB
# USING CUDA AND GPU.
# # GPU MEMORY nvidia-smi in MB={0: 14}
# TEST ON TRAINING SET
#
# PREDICTION OF INITIAL CONDITIONS
# IC 1/10, 10.000%
# PREDICTION - Dynamics pre-run: T 2000/2000, 100.000%: T 281/2000, 14.050%
# PREDICTION:
# PREDICTION: T 7000/7000, 100.000%00, 3.743%ICTION: T 5339/7000, 76.271%
# SEQUENCE PREDICTED...
# IC 2/10, 20.000%
# PREDICTION - Dynamics pre-run: T 2000/2000, 100.000%re-run: T 1798/2000, 89.900%
# PREDICTION:
# PREDICTION: T 7000/7000, 100.000%7/7000, 33.814%79/7000, 98.271%
# SEQUENCE PREDICTED...
# IC 3/10, 30.000%
# PREDICTION - Dynamics pre-run: T 2000/2000, 100.000%0, 10.100%
# PREDICTION:
# PREDICTION: T 7000/7000, 100.000%
# SEQUENCE PREDICTED...
# IC 4/10, 40.000%
# PREDICTION - Dynamics pre-run: T 2000/2000, 100.000%
# ...

# %%
# !bash ./3_Paralleled_ESN_Plot.sh
# Out:
# CUDA Device available? True
# Using device: cuda
# DEVICE NAME: NVIDIA GeForce RTX 4090
# MEMORY USAGE:
# Memory allocated: 0.0 GB
# Max memory allocated: 0.0 GB
# Memory cached:    0.0 GB
# MAX memory cached:    0.0 GB
# USING CUDA AND GPU.
# # GPU MEMORY nvidia-smi in MB={0: 14}
# TEST ON TRAINING SET
#
# PREDICTION OF INITIAL CONDITIONS
# IC 1/10, 10.000%
# PREDICTION - Dynamics pre-run: T 2000/2000, 100.000%- Dynamics pre-run: T 163/2000, 8.150%
# PREDICTION:
# PREDICTION: T 7000/7000, 100.000%
# SEQUENCE PREDICTED...
# IC 2/10, 20.000%
# PREDICTION - Dynamics pre-run: T 2000/2000, 100.000%
# PREDICTION:
# PREDICTION: T 7000/7000, 100.000%DICTION: T 1789/7000, 25.557%
# SEQUENCE PREDICTED...
# IC 3/10, 30.000%
# PREDICTION - Dynamics pre-run: T 2000/2000, 100.000%
# PREDICTION:
# PREDICTION: T 7000/7000, 100.000%, 79.443%
# SEQUENCE PREDICTED...
# IC 4/10, 40.000%
# PREDICTION - Dynamics pre-run: T 2000/2000, 100.000%
# PREDICTION:
# PREDICTION: T 7000/7000, 100.000%
# ...
