# %%
# !bash ./2_AsymPGClustered_ESN_Plot_Tuned_Model.sh "plot_tuned_model" 50 1 1 0 "random_search.json"
# Out:
# CUDA Device available? True
# Using device: cuda
# DEVICE NAME: NVIDIA GeForce RTX 4090
# MEMORY USAGE:
# Memory allocated: 0.0 GB
# Max memory allocated: 0.0 GB
# Memory cached:    0.0 GB
# MAX memory cached:    0.0 GB
# USING CUDA AND GPU.
# # GPU MEMORY nvidia-smi in MB={0: 10903}
# RANDOM SEED: 0
# /home/user/kuei_jan_CHU/PGClustered_ESN/Methods/./Utils/plotting_utils.py:169: RuntimeWarning: divide by zero encountered in log
#   plt.plot(np.log(np.arange(np.shape(error)[0])), np.log(error), label='log(error)')
# IC_IDX: 44000,
# VMIN: -24.061047944869955
# VMAX: 45.40324471014943
#
# IC_IDX: 79000,
# VMIN: -23.089284958935586
# VMAX: 45.09444283968315
#
# IC_IDX: 30000,
# VMIN: -24.6216874642743
# VMAX: 45.563029652459534
#
# IC_IDX: 37000,
# VMIN: -23.700986242004227
# VMAX: 45.231765787625044
#
# IC_IDX: 16000,
# VMIN: -25.41626533130798
# VMAX: 45.96149039196353
#
# IC_IDX: 23000,
# VMIN: -22.612676716159218
# VMAX: 43.71500787584802

# %%
# !bash ./AsymPGClustered_ESN_Train.sh
# Out:
# CUDA Device available? True
# Using device: cuda
# DEVICE NAME: NVIDIA GeForce RTX 4090
# MEMORY USAGE:
# Memory allocated: 0.0 GB
# Max memory allocated: 0.0 GB
# Memory cached:    0.0 GB
# MAX memory cached:    0.0 GB
# USING CUDA AND GPU.
# # GPU MEMORY nvidia-smi in MB={0: 14}
# RANDOM SEED: 0
# Adding noise to the training data. 5 per mille
# ##Using 3/3 dimensions and 100000/100000 samples ##
# SCALING
# Initializing the input weights...
# Initializing the reservoir weights...
# NETWORK SPARSITY: 1.0
# Computing sparse hidden to hidden weight matrix...
# EIGENVALUE DECOMPOSITION
#
# TRAINING: Dynamics prerun...
# TRAINING - Dynamics prerun: T 2000/2000, 100.000%
# TRAINING: Teacher forcing...
# TRAINING - Teacher forcing: T 97999/97999, 100.000%
# TEACHER FORCING ENDED.
#
# TRAINING: COMPUTING THE OUTPUT WEIGHTS...
# FINALISING WEIGHTS...
# COMPUTING NUMBER OF PARAMETERS...
# Number of trainable parameters: 603
# Total number of parameters: 41607
# SAVING MODEL...
# ...

# %%
# !bash ./AsymPGClustered_ESN_Test.sh
# Out:
# CUDA Device available? True
# Using device: cuda
# DEVICE NAME: NVIDIA GeForce RTX 4090
# MEMORY USAGE:
# Memory allocated: 0.0 GB
# Max memory allocated: 0.0 GB
# Memory cached:    0.0 GB
# MAX memory cached:    0.0 GB
# USING CUDA AND GPU.
# # GPU MEMORY nvidia-smi in MB={0: 3749}
# RANDOM SEED: 0
# TEST ON TRAINING SET
# IC 1/10, 10.000%
# PREDICTION - Dynamics prerun
# PREDICTION - Dynamics prerun: T 2000/2000, 100.000%
# PREDICTION:
# SEQUENCE PREDICTED...00, 100.000%
#
# IC 2/10, 20.000%
# PREDICTION - Dynamics prerun
# PREDICTION - Dynamics prerun: T 2000/2000, 100.000%
# PREDICTION:
# SEQUENCE PREDICTED...00, 100.000%
#
# IC 3/10, 30.000%
# PREDICTION - Dynamics prerun
# PREDICTION - Dynamics prerun: T 2000/2000, 100.000%
# PREDICTION:
# SEQUENCE PREDICTED...00, 100.000%
#
# IC 4/10, 40.000%
# PREDICTION - Dynamics prerun
# PREDICTION - Dynamics prerun: T 2000/2000, 100.000%
# PREDICTION:
# SEQUENCE PREDICTED...00, 100.000%
#
# IC 5/10, 50.000%
# PREDICTION - Dynamics prerun
# ...
