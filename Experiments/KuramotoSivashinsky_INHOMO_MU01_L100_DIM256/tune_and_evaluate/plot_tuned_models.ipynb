# %%
# !bash ./2_PGClustered_ESN_Plot_Tuned_Model.sh "plot_tuned_model" 2000 3 "grid_search.json"
# Out:
# {'radius': 0.1, 'sigma_input': 0.1}
# CUDA Device available? True
# Using device: cuda
# DEVICE NAME: NVIDIA GeForce RTX 4090
# MEMORY USAGE:
# Memory allocated: 0.0 GB
# Max memory allocated: 0.0 GB
# Memory cached:    0.0 GB
# MAX memory cached:    0.0 GB
# USING CUDA AND GPU.
# # GPU MEMORY nvidia-smi in MB={0: 14}
# RANDOM SEED: 0
# TEST ON TRAINING SET
# IC 1/10, 10.000%
# PREDICTION - Dynamics prerun
# PREDICTION - Dynamics prerun: T 2000/2000, 100.000%
# PREDICTION:
# SEQUENCE PREDICTED...00, 100.000%
#
# IC 2/10, 20.000%
# PREDICTION - Dynamics prerun
# PREDICTION - Dynamics prerun: T 2000/2000, 100.000%
# PREDICTION:
# SEQUENCE PREDICTED...00, 100.000%
#
# IC 3/10, 30.000%
# PREDICTION - Dynamics prerun
# PREDICTION - Dynamics prerun: T 2000/2000, 100.000%
# PREDICTION:
# SEQUENCE PREDICTED...00, 100.000%
#
# IC 4/10, 40.000%
# PREDICTION - Dynamics prerun
# PREDICTION - Dynamics prerun: T 2000/2000, 100.000%
# PREDICTION:
# SEQUENCE PREDICTED...00, 100.000%
#
# IC 5/10, 50.000%
# PREDICTION - Dynamics prerun
# PREDICTION - Dynamics prerun: T 2000/2000, 100.000%
# PREDICTION:
# SEQUENCE PREDICTED...00, 100.000%
#
# IC 6/10, 60.000%
# PREDICTION - Dynamics prerun
# PREDICTION - Dynamics prerun: T 2000/2000, 100.000%
# PREDICTION:
# SEQUENCE PREDICTED...00, 100.000%
#
# IC 7/10, 70.000%
# PREDICTION - Dynamics prerun
# PREDICTION - Dynamics prerun: T 2000/2000, 100.000%
# PREDICTION:
# SEQUENCE PREDICTED...00, 100.000%
#
# IC 8/10, 80.000%
# PREDICTION - Dynamics prerun
# PREDICTION - Dynamics prerun: T 2000/2000, 100.000%
# PREDICTION:
# SEQUENCE PREDICTED...00, 100.000%
#
# IC 9/10, 90.000%
# PREDICTION - Dynamics prerun
# PREDICTION - Dynamics prerun: T 2000/2000, 100.000%
# PREDICTION:
# SEQUENCE PREDICTED...00, 100.000%
#
# IC 10/10, 100.000%
# PREDICTION - Dynamics prerun
# PREDICTION - Dynamics prerun: T 2000/2000, 100.000%
# PREDICTION:
# SEQUENCE PREDICTED...00, 100.000%
#
# TRAJECTORIES SHAPES:
# (10, 7000, 256)
# (10, 7000, 256)
# AVERAGE RMNSE ERROR: 1.3766224812080998
# AVG NUMBER OF ACCURATE 0.5 PREDICTIONS: 2.211645311597677
# AVG NUMBER OF ACCURATE 1 PREDICTIONS: 3.4228791198377713
# POWER SPECTRUM MEAN ERROR: 0.7371644588957863
# TEMPORAL DISTANCE: 0.12693053707287918
# GEOMETRICAL DISTANCE: inf
# IC INDEXES OF TRAIN PREDICTED...
#
#
# TEST ON TESTING SET
# IC 1/10, 10.000%
# PREDICTION - Dynamics prerun
# PREDICTION - Dynamics prerun: T 2000/2000, 100.000%
# PREDICTION:
# SEQUENCE PREDICTED...00, 100.000%
#
# IC 2/10, 20.000%
# PREDICTION - Dynamics prerun
# PREDICTION - Dynamics prerun: T 2000/2000, 100.000%
# PREDICTION:
# SEQUENCE PREDICTED...00, 100.000%
#
# IC 3/10, 30.000%
# PREDICTION - Dynamics prerun
# PREDICTION - Dynamics prerun: T 2000/2000, 100.000%
# PREDICTION:
# SEQUENCE PREDICTED...00, 100.000%
#
# IC 4/10, 40.000%
# PREDICTION - Dynamics prerun
# PREDICTION - Dynamics prerun: T 2000/2000, 100.000%
# PREDICTION:
# SEQUENCE PREDICTED...00, 100.000%
#
# IC 5/10, 50.000%
# PREDICTION - Dynamics prerun
# PREDICTION - Dynamics prerun: T 2000/2000, 100.000%
# PREDICTION:
# SEQUENCE PREDICTED...00, 100.000%
#
# IC 6/10, 60.000%
# PREDICTION - Dynamics prerun
# PREDICTION - Dynamics prerun: T 2000/2000, 100.000%
# PREDICTION:
# SEQUENCE PREDICTED...00, 100.000%
#
# IC 7/10, 70.000%
# PREDICTION - Dynamics prerun
# PREDICTION - Dynamics prerun: T 2000/2000, 100.000%
# PREDICTION:
# SEQUENCE PREDICTED...00, 100.000%
#
# IC 8/10, 80.000%
# PREDICTION - Dynamics prerun
# PREDICTION - Dynamics prerun: T 2000/2000, 100.000%
# PREDICTION:
# SEQUENCE PREDICTED...00, 100.000%
#
# IC 9/10, 90.000%
# PREDICTION - Dynamics prerun
# PREDICTION - Dynamics prerun: T 2000/2000, 100.000%
# PREDICTION:
# SEQUENCE PREDICTED...00, 100.000%
#
# IC 10/10, 100.000%
# PREDICTION - Dynamics prerun
# PREDICTION - Dynamics prerun: T 2000/2000, 100.000%
# PREDICTION:
# SEQUENCE PREDICTED...00, 100.000%
#
# TRAJECTORIES SHAPES:
# (10, 7000, 256)
# (10, 7000, 256)
# AVERAGE RMNSE ERROR: 1.3734679422740927
# AVG NUMBER OF ACCURATE 0.5 PREDICTIONS: 1.8098895985196815
# AVG NUMBER OF ACCURATE 1 PREDICTIONS: 3.142445676550656
# POWER SPECTRUM MEAN ERROR: 0.44363732480068496
# TEMPORAL DISTANCE: 0.12559280971416883
# GEOMETRICAL DISTANCE: inf
# IC INDEXES OF TEST PREDICTED...
#
#
# /home/user/kuei_jan_CHU/PGClustered_ESN/Methods/./Utils/plotting_utils.py:189: RuntimeWarning: divide by zero encountered in log
#   plt.plot(np.log(np.arange(np.shape(error)[0])), np.log(error), label='log(error)')
# IC_IDX: 44000,
# VMIN: -3
# VMAX: 3
#
# /home/user/kuei_jan_CHU/PGClustered_ESN/Methods/./Utils/plotting_utils.py:189: RuntimeWarning: divide by zero encountered in log
#   plt.plot(np.log(np.arange(np.shape(error)[0])), np.log(error), label='log(error)')
# IC_IDX: 79000,
# VMIN: -3
# VMAX: 3
#
# /home/user/kuei_jan_CHU/PGClustered_ESN/Methods/./Utils/plotting_utils.py:189: RuntimeWarning: divide by zero encountered in log
#   plt.plot(np.log(np.arange(np.shape(error)[0])), np.log(error), label='log(error)')
# IC_IDX: 30000,
# VMIN: -3
# VMAX: 3
#
# /home/user/kuei_jan_CHU/PGClustered_ESN/Methods/./Utils/plotting_utils.py:189: RuntimeWarning: divide by zero encountered in log
#   plt.plot(np.log(np.arange(np.shape(error)[0])), np.log(error), label='log(error)')
# IC_IDX: 37000,
# VMIN: -3
# VMAX: 3
#
# /home/user/kuei_jan_CHU/PGClustered_ESN/Methods/./Utils/plotting_utils.py:189: RuntimeWarning: divide by zero encountered in log
#   plt.plot(np.log(np.arange(np.shape(error)[0])), np.log(error), label='log(error)')
# IC_IDX: 16000,
# VMIN: -3
# VMAX: 3
#
# /home/user/kuei_jan_CHU/PGClustered_ESN/Methods/./Utils/plotting_utils.py:189: RuntimeWarning: divide by zero encountered in log
#   plt.plot(np.log(np.arange(np.shape(error)[0])), np.log(error), label='log(error)')
# IC_IDX: 23000,
# VMIN: -3
# VMAX: 3

# %%
# !bash ./2_Randomly_Clustered_ESN_Plot_Tuned_Model.sh "plot_tuned_model" 2000 3 "grid_search.json"
# Out:
# {'radius': 0.1, 'sigma_input': 0.1}
# /home/user/kuei_jan_CHU/PGClustered_ESN/Methods/./Utils/plotting_utils.py:189: RuntimeWarning: divide by zero encountered in log
#   plt.plot(np.log(np.arange(np.shape(error)[0])), np.log(error), label='log(error)')
# IC_IDX: 44000,
# VMIN: -3
# VMAX: 3
#
# /home/user/kuei_jan_CHU/PGClustered_ESN/Methods/./Utils/plotting_utils.py:189: RuntimeWarning: divide by zero encountered in log
#   plt.plot(np.log(np.arange(np.shape(error)[0])), np.log(error), label='log(error)')
# IC_IDX: 79000,
# VMIN: -3
# VMAX: 3
#
# /home/user/kuei_jan_CHU/PGClustered_ESN/Methods/./Utils/plotting_utils.py:189: RuntimeWarning: divide by zero encountered in log
#   plt.plot(np.log(np.arange(np.shape(error)[0])), np.log(error), label='log(error)')
# IC_IDX: 30000,
# VMIN: -3
# VMAX: 3
#
# /home/user/kuei_jan_CHU/PGClustered_ESN/Methods/./Utils/plotting_utils.py:189: RuntimeWarning: divide by zero encountered in log
#   plt.plot(np.log(np.arange(np.shape(error)[0])), np.log(error), label='log(error)')
# IC_IDX: 37000,
# VMIN: -3
# VMAX: 3
#
# /home/user/kuei_jan_CHU/PGClustered_ESN/Methods/./Utils/plotting_utils.py:189: RuntimeWarning: divide by zero encountered in log
#   plt.plot(np.log(np.arange(np.shape(error)[0])), np.log(error), label='log(error)')
# IC_IDX: 16000,
# VMIN: -3
# VMAX: 3
#
# /home/user/kuei_jan_CHU/PGClustered_ESN/Methods/./Utils/plotting_utils.py:189: RuntimeWarning: divide by zero encountered in log
#   plt.plot(np.log(np.arange(np.shape(error)[0])), np.log(error), label='log(error)')
# IC_IDX: 23000,
# VMIN: -3
# VMAX: 3

# %%
# !bash ./2_Standard_ESN_Plot_Tuned_Model.sh "plot_tuned_model" 2000 3 "grid_search.json"
# Out:
# {'radius': 0.99, 'sigma_input': 0.5}
# /home/user/kuei_jan_CHU/PGClustered_ESN/Methods/./Utils/plotting_utils.py:189: RuntimeWarning: divide by zero encountered in log
#   plt.plot(np.log(np.arange(np.shape(error)[0])), np.log(error), label='log(error)')
# IC_IDX: 44000,
# VMIN: -3
# VMAX: 3
#
# /home/user/kuei_jan_CHU/PGClustered_ESN/Methods/./Utils/plotting_utils.py:189: RuntimeWarning: divide by zero encountered in log
#   plt.plot(np.log(np.arange(np.shape(error)[0])), np.log(error), label='log(error)')
# IC_IDX: 79000,
# VMIN: -3
# VMAX: 3
#
# /home/user/kuei_jan_CHU/PGClustered_ESN/Methods/./Utils/plotting_utils.py:189: RuntimeWarning: divide by zero encountered in log
#   plt.plot(np.log(np.arange(np.shape(error)[0])), np.log(error), label='log(error)')
# IC_IDX: 30000,
# VMIN: -3
# VMAX: 3
#
# /home/user/kuei_jan_CHU/PGClustered_ESN/Methods/./Utils/plotting_utils.py:189: RuntimeWarning: divide by zero encountered in log
#   plt.plot(np.log(np.arange(np.shape(error)[0])), np.log(error), label='log(error)')
# IC_IDX: 37000,
# VMIN: -3
# VMAX: 3
#
# /home/user/kuei_jan_CHU/PGClustered_ESN/Methods/./Utils/plotting_utils.py:189: RuntimeWarning: divide by zero encountered in log
#   plt.plot(np.log(np.arange(np.shape(error)[0])), np.log(error), label='log(error)')
# IC_IDX: 16000,
# VMIN: -3
# VMAX: 3
#
# /home/user/kuei_jan_CHU/PGClustered_ESN/Methods/./Utils/plotting_utils.py:189: RuntimeWarning: divide by zero encountered in log
#   plt.plot(np.log(np.arange(np.shape(error)[0])), np.log(error), label='log(error)')
# IC_IDX: 23000,
# VMIN: -3
# VMAX: 3

# %%
# !bash ./2_Paralleled_ESN_Plot_Tuned_Model.sh "plot_tuned_model" 2000 3 "grid_search.json"
# Out:
# {'radius': 0.4, 'sigma_input': 0.1}
